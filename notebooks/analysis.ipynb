# %%
import numpy as np

# %%
import pandas as pd
import numpy as np
import sys, os
import importlib
sys.path.insert(0, os.path.abspath('../'))
import textmining.cluster_analysis as cluster_analysis
import textmining.lexicons as lexicons

importlib.reload(textmining.cluster_analysis)
importlib.reload(textmining.lexicons)
# Out:
# <module 'textmining.lexicons' from 'C:\\Users\\elba_ro\\Documents\\projects\\conf21-style-transfer\\textmining\\lexicons.py'>

# %%
conservative_arguments_df = pd.read_csv('../data/conservative_debate_arguments_w_effect.csv')
liberal_arguments_df = pd.read_csv('../data/liberal_debate_arguments_w_effect.csv')

# %%
conservative_arguments_df['category'].value_counts().to_frame().plot(kind="bar")
liberal_arguments_df['category'].value_counts().to_frame().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
conservative_arguments_df['effect'].value_counts().to_frame().plot(kind="bar")
liberal_arguments_df['effect'].value_counts().to_frame().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Extract Features

# %%
conservative_arguments_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'debate_id', 'p_name', 'effects', 'effect_count',
#        'top_effect', 'effect', 'category', 'round', 'argument'],
#       dtype='object')

# %%
#nrc
liberal_arguments_df = lexicons.count_nrc_emotions_and_sentiments(liberal_arguments_df, text_column= 'argument')
conservative_arguments_df = lexicons.count_nrc_emotions_and_sentiments(conservative_arguments_df, text_column= 'argument')

# %%
#mpqa
