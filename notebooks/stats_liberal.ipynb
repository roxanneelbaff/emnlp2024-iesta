# %%
import pandas as pd
import numpy as np
from glob import glob
from iesta.machine_learning.dataloader import IESTAData, METHODOLOGY

from iesta.machine_learning.feature_extraction import get_features_df
import iesta.loader as loader
import iesta.properties as prop  
import iesta.processor as proc  
from iesta.machine_learning.dataloader import IESTAData, METHODOLOGY

#from .autonotebook import tqdm as notebook_tqdm

import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

sns.reset_defaults()
sns.set(
    rc={'figure.figsize':(3,2)}, 
    #style="white" # nicer layout
)
# Out:
# /home/elba_ro/repos/conf22-style-transfer/iesta_venv/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
ideology = prop.LIBERAL_IDEOLOGY.lower()
ideology
# Out:
# 'liberal'

# %%
path = "../data/extracted_features/"



dataloader = IESTAData(ideology=ideology, methodology=METHODOLOGY.EACH)

training_df, training_data_path = dataloader.get_training_data()
training_data = pd.read_parquet(training_data_path)
# Out:
# /home/elba_ro/repos/conf22-style-transfer/iesta/../data/splitted_liberal_debate_arguments_effect_test0.3_random2.parquet
# iesta        INFO     File already created. Loading file...

# %%
len(training_data)
# Out:
# 46792

# %% [markdown]
# ## Fetching MPQA and EMPATH

# %%
style_features_path = glob(f"{path}/{ideology}_style-features_1000/*.parquet")
transformer_features_path = glob(f"{path}/{ideology}_transformer-features_100/*.parquet")

# %%
style_features_df = get_features_df(style_features_path, 1000, training_data)
transformer_features_df = get_features_df(transformer_features_path, 100, training_data)
# Out:
# 792: ../data/extracted_features//liberal_style-features_1000/liberal_batch1000_47_style-features.parquet
# 92: ../data/extracted_features//liberal_transformer-features_100/liberal_batch100_468_transformer-features.parquet

# %% [markdown]
# ## Running significance tests

# %% [markdown]
# ### All Effects

# %%
import iesta.stats.significance
significance_empath_mpqa_effects_df = iesta.stats.significance.calc_sign_effects(
                        style_features_df, 
                        "liberal", 
                        "empath-mpqa", 
                        "effect", 
                        exclude_iv_vals = [])

significance_transformers_effects_df = iesta.stats.significance.calc_sign_effects(
                        transformer_features_df, 
                        "liberal", 
                        "transformers", 
                        "effect", 
                        exclude_iv_vals = [])
# Out:
# data has 46792 instances
# bonforrini_threshold:  0.008333333333333333
# there are 408 features.
# Feature: mpqa_assessments
# Feature: mpqa_doubt
# Feature: mpqa_authority
# Feature: mpqa_emphasis
# Feature: mpqa_necessity
# Feature: mpqa_causation
# Feature: mpqa_generalization
# Feature: mpqa_structure
# Feature: mpqa_conditionals
# Feature: mpqa_inconsistency
# Feature: mpqa_possibility
# Feature: mpqa_wants
# Feature: mpqa_contrast
# Feature: mpqa_priority
# Feature: mpqa_difficulty
# Feature: mpqa_inyourshoes
# Feature: mpqa_rhetoricalquestion
# Feature: mpqa_argumentative
# Feature: mpqa_token_ratio
# Feature: mpqa_args_count
# Feature: empath_cold_count
# Feature: empath_cold_ratio
# Feature: empath_aggression_count
# Feature: empath_aggression_ratio
# Feature: empath_vacation_count
# Feature: empath_vacation_ratio
# Feature: empath_dispute_count
# Feature: empath_dispute_ratio
# Feature: empath_nervousness_count
# Feature: empath_nervousness_ratio
# Feature: empath_leisure_count
# Feature: empath_leisure_ratio
# Feature: empath_journalism_count
# Feature: empath_journalism_ratio
# Feature: empath_kill_count
# Feature: empath_kill_ratio
# Feature: empath_play_count
# Feature: empath_play_ratio
# Feature: empath_college_count
# Feature: empath_college_ratio
# Feature: empath_optimism_count
# Feature: empath_optimism_ratio
# Feature: empath_driving_count
# Feature: empath_driving_ratio
# Feature: empath_childish_count
# Feature: empath_childish_ratio
# Feature: empath_internet_count
# Feature: empath_internet_ratio
# Feature: empath_reading_count
# Feature: empath_reading_ratio
# Feature: empath_body_count
# Feature: empath_body_ratio
# Feature: empath_celebration_count
# Feature: empath_celebration_ratio
# Feature: empath_violence_count
# Feature: empath_violence_ratio
# Feature: empath_love_count
# Feature: empath_love_ratio
# Feature: empath_communication_count
# Feature: empath_communication_ratio
# Feature: empath_trust_count
# Feature: empath_trust_ratio
# Feature: empath_deception_count
# Feature: empath_deception_ratio
# Feature: empath_fight_count
# Feature: empath_fight_ratio
# Feature: empath_toy_count
# Feature: empath_toy_ratio
# Feature: empath_war_count
# Feature: empath_war_ratio
# Feature: empath_speaking_count
# Feature: empath_speaking_ratio
# Feature: empath_phone_count
# Feature: empath_phone_ratio
# Feature: empath_science_count
# Feature: empath_science_ratio
# Feature: empath_youth_count
# Feature: empath_youth_ratio
# Feature: empath_fun_count
# Feature: empath_fun_ratio
# Feature: empath_shame_count
# Feature: empath_shame_ratio
# Feature: empath_party_count
# Feature: empath_party_ratio
# Feature: empath_pain_count
# Feature: empath_pain_ratio
# Feature: empath_philosophy_count
# Feature: empath_philosophy_ratio
# Feature: empath_negative_emotion_count
# Feature: empath_negative_emotion_ratio
# Feature: empath_competing_count
# Feature: empath_competing_ratio
# Feature: empath_friends_count
# Feature: empath_friends_ratio
# Feature: empath_weapon_count
# Feature: empath_weapon_ratio
# Feature: empath_children_count
# Feature: empath_children_ratio
# Feature: empath_contentment_count
# Feature: empath_contentment_ratio
# Feature: empath_writing_count
# Feature: empath_writing_ratio
# Feature: empath_help_count
# Feature: empath_help_ratio
# Feature: empath_money_count
# Feature: empath_money_ratio
# Feature: empath_crime_count
# Feature: empath_crime_ratio
# Feature: empath_government_count
# Feature: empath_government_ratio
# Feature: empath_suffering_count
# Feature: empath_suffering_ratio
# Feature: empath_school_count
# Feature: empath_school_ratio
# Feature: empath_magic_count
# Feature: empath_magic_ratio
# Feature: empath_morning_count
# Feature: empath_morning_ratio
# Feature: empath_ridicule_count
# Feature: empath_ridicule_ratio
# Feature: empath_computer_count
# Feature: empath_computer_ratio
# Feature: empath_stealing_count
# Feature: empath_stealing_ratio
# Feature: empath_divine_count
# Feature: empath_divine_ratio
# Feature: empath_business_count
# Feature: empath_business_ratio
# Feature: empath_independence_count
# Feature: empath_independence_ratio
# Feature: empath_movement_count
# Feature: empath_movement_ratio
# Feature: empath_confusion_count
# Feature: empath_confusion_ratio
# Feature: empath_sports_count
# Feature: empath_sports_ratio
# Feature: empath_healing_count
# Feature: empath_healing_ratio
# Feature: empath_legend_count
# Feature: empath_legend_ratio
# Feature: empath_heroic_count
# Feature: empath_heroic_ratio
# Feature: empath_programming_count
# Feature: empath_programming_ratio
# Feature: empath_dominant_personality_count
# Feature: empath_dominant_personality_ratio
# Feature: empath_meeting_count
# Feature: empath_meeting_ratio
# Feature: empath_gain_count
# Feature: empath_gain_ratio
# Feature: empath_injury_count
# Feature: empath_injury_ratio
# Feature: empath_work_count
# Feature: empath_work_ratio
# Feature: empath_valuable_count
# Feature: empath_valuable_ratio
# Feature: empath_sadness_count
# Feature: empath_sadness_ratio
# Feature: empath_traveling_count
# Feature: empath_traveling_ratio
# Feature: empath_strength_count
# Feature: empath_strength_ratio
# Feature: empath_technology_count
# Feature: empath_technology_ratio
# Feature: empath_shape_and_size_count
# Feature: empath_shape_and_size_ratio
# Feature: empath_power_count
# Feature: empath_power_ratio
# Feature: empath_white_collar_job_count
# Feature: empath_white_collar_job_ratio
# Feature: empath_law_count
# Feature: empath_law_ratio
# Feature: empath_giving_count
# Feature: empath_giving_ratio
# Feature: empath_positive_emotion_count
# Feature: empath_positive_emotion_ratio
# Feature: empath_wedding_count
# Feature: empath_wedding_ratio
# Feature: empath_attractive_count
# Feature: empath_attractive_ratio
# Feature: empath_tourism_count
# Feature: empath_tourism_ratio
# Feature: empath_social_media_count
# Feature: empath_social_media_ratio
# Feature: empath_real_estate_count
# Feature: empath_real_estate_ratio
# Feature: empath_hipster_count
# Feature: empath_hipster_ratio
# Feature: empath_hearing_count
# Feature: empath_hearing_ratio
# Feature: empath_weather_count
# Feature: empath_weather_ratio
# Feature: empath_music_count
# Feature: empath_music_ratio
# Feature: empath_listen_count
# Feature: empath_listen_ratio
# Feature: empath_car_count
# Feature: empath_car_ratio
# Feature: empath_messaging_count
# Feature: empath_messaging_ratio
# Feature: empath_achievement_count
# Feature: empath_achievement_ratio
# Feature: empath_rural_count
# Feature: empath_rural_ratio
# Feature: empath_musical_count
# Feature: empath_musical_ratio
# Feature: empath_office_count
# Feature: empath_office_ratio
# Feature: empath_sleep_count
# Feature: empath_sleep_ratio
# Feature: empath_furniture_count
# Feature: empath_furniture_ratio
# Feature: empath_home_count
# Feature: empath_home_ratio
# Feature: empath_military_count
# Feature: empath_military_ratio
# Feature: empath_order_count
# Feature: empath_order_ratio
# Feature: empath_air_travel_count
# Feature: empath_air_travel_ratio
# Feature: empath_emotional_count
# Feature: empath_emotional_ratio
# Feature: empath_politics_count
# Feature: empath_politics_ratio
# Feature: empath_cleaning_count
# Feature: empath_cleaning_ratio
# Feature: empath_hate_count
# Feature: empath_hate_ratio
# Feature: empath_banking_count
# Feature: empath_banking_ratio
# Feature: empath_shopping_count
# Feature: empath_shopping_ratio
# Feature: empath_appearance_count
# Feature: empath_appearance_ratio
# Feature: empath_disappointment_count
# Feature: empath_disappointment_ratio
# Feature: empath_noise_count
# Feature: empath_noise_ratio
# Feature: empath_sound_count
# Feature: empath_sound_ratio
# Feature: empath_alcohol_count
# Feature: empath_alcohol_ratio
# Feature: empath_liquid_count
# Feature: empath_liquid_ratio
# Feature: empath_feminine_count
# Feature: empath_feminine_ratio
# Feature: empath_dance_count
# Feature: empath_dance_ratio
# Feature: empath_family_count
# Feature: empath_family_ratio
# Feature: empath_fear_count
# Feature: empath_fear_ratio
# Feature: empath_vehicle_count
# Feature: empath_vehicle_ratio
# Feature: empath_tool_count
# Feature: empath_tool_ratio
# Feature: empath_economics_count
# Feature: empath_economics_ratio
# Feature: empath_breaking_count
# Feature: empath_breaking_ratio
# Feature: empath_animal_count
# Feature: empath_animal_ratio
# Feature: empath_exercise_count
# Feature: empath_exercise_ratio
# Feature: empath_leader_count
# Feature: empath_leader_ratio
# Feature: empath_restaurant_count
# Feature: empath_restaurant_ratio
# Feature: empath_fabric_count
# Feature: empath_fabric_ratio
# Feature: empath_fire_count
# Feature: empath_fire_ratio
# Feature: empath_warmth_count
# Feature: empath_warmth_ratio
# Feature: empath_clothing_count
# Feature: empath_clothing_ratio
# Feature: empath_fashion_count
# Feature: empath_fashion_ratio
# Feature: empath_domestic_work_count
# Feature: empath_domestic_work_ratio
# Feature: empath_medical_emergency_count
# Feature: empath_medical_emergency_ratio
# Feature: empath_occupation_count
# Feature: empath_occupation_ratio
# Feature: empath_wealthy_count
# Feature: empath_wealthy_ratio
# Feature: empath_blue_collar_job_count
# Feature: empath_blue_collar_job_ratio
# Feature: empath_art_count
# Feature: empath_art_ratio
# Feature: empath_cooking_count
# Feature: empath_cooking_ratio
# Feature: empath_religion_count
# Feature: empath_religion_ratio
# Feature: empath_surprise_count
# Feature: empath_surprise_ratio
# Feature: empath_worship_count
# Feature: empath_worship_ratio
# Feature: empath_eating_count
# Feature: empath_eating_ratio
# Feature: empath_death_count
# Feature: empath_death_ratio
# Feature: empath_dominant_heirarchical_count
# Feature: empath_dominant_heirarchical_ratio
# Feature: empath_neglect_count
# Feature: empath_neglect_ratio
# Feature: empath_hiking_count
# Feature: empath_hiking_ratio
# Feature: empath_farming_count
# Feature: empath_farming_ratio
# Feature: empath_urban_count
# Feature: empath_urban_ratio
# Feature: empath_rage_count
# Feature: empath_rage_ratio
# Feature: empath_torment_count
# Feature: empath_torment_ratio
# Feature: empath_poor_count
# Feature: empath_poor_ratio
# Feature: empath_plant_count
# Feature: empath_plant_ratio
# Feature: empath_beauty_count
# Feature: empath_beauty_ratio
# Feature: empath_negotiate_count
# Feature: empath_negotiate_ratio
# Feature: empath_payment_count
# Feature: empath_payment_ratio
# Feature: empath_cheerfulness_count
# Feature: empath_cheerfulness_ratio
# Feature: empath_masculine_count
# Feature: empath_masculine_ratio
# Feature: empath_prison_count
# Feature: empath_prison_ratio
# Feature: empath_beach_count
# Feature: empath_beach_ratio
# Feature: empath_water_count
# Feature: empath_water_ratio
# Feature: empath_swimming_count
# Feature: empath_swimming_ratio
# Feature: empath_exotic_count
# Feature: empath_exotic_ratio
# Feature: empath_sailing_count
# Feature: empath_sailing_ratio
# Feature: empath_ugliness_count
# Feature: empath_ugliness_ratio
# Feature: empath_ship_count
# Feature: empath_ship_ratio
# Feature: empath_terrorism_count
# Feature: empath_terrorism_ratio
# Feature: empath_monster_count
# Feature: empath_monster_ratio
# Feature: empath_ocean_count
# Feature: empath_ocean_ratio
# Feature: empath_pride_count
# Feature: empath_pride_ratio
# Feature: empath_swearing_terms_count
# Feature: empath_swearing_terms_ratio
# Feature: empath_royalty_count
# Feature: empath_royalty_ratio
# Feature: empath_sexual_count
# Feature: empath_sexual_ratio
# Feature: empath_health_count
# Feature: empath_health_ratio
# Feature: empath_hygiene_count
# Feature: empath_hygiene_ratio
# Feature: empath_pet_count
# Feature: empath_pet_ratio
# Feature: empath_smell_count
# Feature: empath_smell_ratio
# Feature: empath_sympathy_count
# Feature: empath_sympathy_ratio
# Feature: empath_lust_count
# Feature: empath_lust_ratio
# Feature: empath_disgust_count
# Feature: empath_disgust_ratio
# Feature: empath_envy_count
# Feature: empath_envy_ratio
# Feature: empath_night_count
# Feature: empath_night_ratio
# Feature: empath_ancient_count
# Feature: empath_ancient_ratio
# Feature: empath_politeness_count
# Feature: empath_politeness_ratio
# Feature: empath_horror_count
# Feature: empath_horror_ratio
# Feature: empath_timidity_count
# Feature: empath_timidity_ratio
# Feature: empath_weakness_count
# Feature: empath_weakness_ratio
# Feature: empath_zest_count
# Feature: empath_zest_ratio
# Feature: empath_joy_count
# Feature: empath_joy_ratio
# Feature: empath_affection_count
# Feature: empath_affection_ratio
# Feature: empath_irritability_count
# Feature: empath_irritability_ratio
# Feature: empath_exasperation_count
# Feature: empath_exasperation_ratio
# Feature: empath_anger_count
# Feature: empath_anger_ratio
# Feature: empath_medieval_count
# Feature: empath_medieval_ratio
# Feature: empath_anticipation_count
# Feature: empath_anticipation_ratio
# Feature: empath_anonymity_count
# Feature: empath_anonymity_ratio
# Feature: empath_superhero_count
# Feature: empath_superhero_ratio
# data has 46792 instances
# bonforrini_threshold:  0.008333333333333333
# there are 37 features.
# Feature: emotion_hartmann_anger
# Feature: emotion_hartmann_anger_count
# Feature: emotion_hartmann_anger_ratio
# Feature: emotion_hartmann_disgust
# Feature: emotion_hartmann_disgust_count
# Feature: emotion_hartmann_disgust_ratio
# Feature: emotion_hartmann_fear
# Feature: emotion_hartmann_fear_count
# Feature: emotion_hartmann_fear_ratio
# Feature: emotion_hartmann_joy
# Feature: emotion_hartmann_joy_count
# Feature: emotion_hartmann_joy_ratio
# Feature: emotion_hartmann_neutral
# Feature: emotion_hartmann_neutral_count
# Feature: emotion_hartmann_neutral_ratio
# Feature: emotion_hartmann_sadness
# Feature: emotion_hartmann_sadness_count
# Feature: emotion_hartmann_sadness_ratio
# Feature: emotion_hartmann_surprise
# Feature: emotion_hartmann_surprise_count
# Feature: emotion_hartmann_surprise_ratio
# Feature: hedge_C_count
# Feature: hedge_C_ratio
# Feature: hedge_E_count
# Feature: hedge_E_ratio
# Feature: hedge_N_count
# Feature: hedge_N_ratio
# Feature: hedge_D_count
# Feature: hedge_D_ratio
# Feature: hedge_I_count
# Feature: hedge_I_ratio
# Feature: toxicity_neutral_count
# Feature: toxicity_neutral_ratio
# Feature: toxicity_neutral
# Feature: toxicity_toxic_count
# Feature: toxicity_toxic_ratio
# Feature: toxicity_toxic

# %%
significance_empath_mpqa_effects_df
# Out:
#                          effective ineffective  effective okay  \
# feature
# mpqa_assessments                           NaN             NaN
# mpqa_doubt                                 NaN             NaN
# mpqa_authority                            0.01             NaN
# mpqa_emphasis                             0.01             NaN
# mpqa_necessity                            0.02             NaN
# mpqa_causation                            0.02             NaN
# mpqa_structure                             NaN             NaN
# mpqa_conditionals                         0.01             NaN
# mpqa_inconsistency                        0.03             NaN
# mpqa_possibility                          0.01             NaN
# mpqa_contrast                             0.02             NaN
# mpqa_priority                             0.01             NaN
# mpqa_rhetoricalquestion                    NaN             NaN
# mpqa_argumentative                        0.03             NaN
# mpqa_token_ratio                           NaN             NaN
# mpqa_args_count                           0.03             NaN
#
#                          effective provocative  ineffective okay  \
# feature
# mpqa_assessments                           NaN             -0.01
# mpqa_doubt                                 NaN             -0.01
# mpqa_authority                             NaN             -0.01
# mpqa_emphasis                              NaN             -0.02
# mpqa_necessity                             NaN             -0.03
# mpqa_causation                             NaN             -0.04
# mpqa_structure                             NaN             -0.02
# mpqa_conditionals                          NaN             -0.01
# mpqa_inconsistency                         NaN             -0.03
# mpqa_possibility                           NaN             -0.02
# mpqa_contrast                              NaN             -0.03
# mpqa_priority                              NaN             -0.01
# mpqa_rhetoricalquestion                    NaN               NaN
# mpqa_argumentative                         NaN             -0.04
# mpqa_token_ratio                           NaN               NaN
# mpqa_args_count                            NaN             -0.04
#
#                          ineffective provocative  okay provocative
# feature
# mpqa_assessments                             NaN               NaN
# mpqa_doubt                                   NaN               NaN
# mpqa_authority                               NaN               NaN
# mpqa_emphasis                                NaN               NaN
# mpqa_necessity                             -0.02               NaN
# mpqa_causation                             -0.01               NaN
# mpqa_structure                               NaN               NaN
# mpqa_conditionals                            NaN               NaN
# mpqa_inconsistency                           NaN               NaN
# mpqa_possibility                             NaN               NaN
# mpqa_contrast                                NaN               NaN
# mpqa_priority                                NaN               NaN
# mpqa_rhetoricalquestion                      NaN               NaN
# mpqa_argumentative                           NaN               NaN
# mpqa_token_ratio                             NaN             -0.03
# mpqa_args_count                              NaN               NaN

# %%
significance_transformers_effects_df
# Out:
#                                 effective ineffective  effective okay  \
# feature
# emotion_hartmann_anger                            NaN             NaN
# emotion_hartmann_anger_count                     0.02             NaN
# emotion_hartmann_disgust                         0.02             NaN
# emotion_hartmann_disgust_count                   0.03             NaN
# emotion_hartmann_disgust_ratio                   0.02             NaN
# emotion_hartmann_fear                             NaN             NaN
# emotion_hartmann_fear_count                       NaN             NaN
# emotion_hartmann_joy                             0.03            0.05
# emotion_hartmann_joy_count                       0.03             NaN
# emotion_hartmann_joy_ratio                       0.02             NaN
# emotion_hartmann_neutral                         0.02             NaN
# emotion_hartmann_neutral_count                   0.04             NaN
# emotion_hartmann_neutral_ratio                   0.01             NaN
# emotion_hartmann_surprise                         NaN             NaN
# hedge_C_count                                    0.02             NaN
# hedge_C_ratio                                     NaN             NaN
# toxicity_neutral_count                           0.04             NaN
#
#                                 effective provocative  ineffective okay  \
# feature
# emotion_hartmann_anger                          -0.06               NaN
# emotion_hartmann_anger_count                      NaN             -0.03
# emotion_hartmann_disgust                          NaN             -0.04
# emotion_hartmann_disgust_count                    NaN             -0.05
# emotion_hartmann_disgust_ratio                    NaN             -0.04
# emotion_hartmann_fear                             NaN               NaN
# emotion_hartmann_fear_count                       NaN             -0.01
# emotion_hartmann_joy                              NaN               NaN
# emotion_hartmann_joy_count                        NaN             -0.03
# emotion_hartmann_joy_ratio                        NaN             -0.02
# emotion_hartmann_neutral                         0.06             -0.01
# emotion_hartmann_neutral_count                   0.06             -0.05
# emotion_hartmann_neutral_ratio                    NaN               NaN
# emotion_hartmann_surprise                         NaN              0.02
# hedge_C_count                                     NaN             -0.02
# hedge_C_ratio                                     NaN               NaN
# toxicity_neutral_count                            NaN             -0.05
#
#                                 ineffective provocative  okay provocative
# feature
# emotion_hartmann_anger                            -0.01               NaN
# emotion_hartmann_anger_count                        NaN               NaN
# emotion_hartmann_disgust                          -0.02               NaN
# emotion_hartmann_disgust_count                    -0.01               NaN
# emotion_hartmann_disgust_ratio                    -0.01               NaN
# emotion_hartmann_fear                               NaN               NaN
# emotion_hartmann_fear_count                         NaN               NaN
# emotion_hartmann_joy                                NaN               NaN
# emotion_hartmann_joy_count                          NaN               NaN
# emotion_hartmann_joy_ratio                          NaN               NaN
# emotion_hartmann_neutral                            NaN               NaN
# emotion_hartmann_neutral_count                      NaN               NaN
# emotion_hartmann_neutral_ratio                      NaN               NaN
# emotion_hartmann_surprise                          0.02               NaN
# hedge_C_count                                     -0.01               NaN
# hedge_C_ratio                                       NaN               NaN
# toxicity_neutral_count                              NaN               NaN

# %% [markdown]
# ### All Effects - Excluding *Okay*

# %%
significance_empath_mpqa_NOOKAY_effects_df = iesta.stats.significance.calc_sign_effects(
                        style_features_df, 
                        "liberal", 
                        "empath-mpqa", 
                        "effect", 
                        exclude_iv_vals = ["okay"])
                        
significance_transformers_NOOKAY_effects_df = iesta.stats.significance.calc_sign_effects(
                        transformer_features_df, 
                        "liberal", 
                        "transformers", 
                        "effect", 
                        exclude_iv_vals = ["okay"])
# Out:
# The IV has
#  ineffective    37713
# okay            6835
# effective       1722
# provocative      522
# Name: effect, dtype: int64. Excluding ['okay']...
# After exclusion:
#  ineffective    37713
# effective       1722
# provocative      522
# Name: effect, dtype: int64. Excluding ['okay']...
# data has 39957 instances
# bonforrini_threshold:  0.016666666666666666
# there are 408 features.
# Feature: mpqa_assessments
# Feature: mpqa_doubt
# Feature: mpqa_authority
# Feature: mpqa_emphasis
# Feature: mpqa_necessity
# Feature: mpqa_causation
# Feature: mpqa_generalization
# Feature: mpqa_structure
# Feature: mpqa_conditionals
# Feature: mpqa_inconsistency
# Feature: mpqa_possibility
# Feature: mpqa_wants
# Feature: mpqa_contrast
# Feature: mpqa_priority
# Feature: mpqa_difficulty
# Feature: mpqa_inyourshoes
# Feature: mpqa_rhetoricalquestion
# Feature: mpqa_argumentative
# Feature: mpqa_token_ratio
# Feature: mpqa_args_count
# Feature: empath_cold_count
# Feature: empath_cold_ratio
# Feature: empath_aggression_count
# Feature: empath_aggression_ratio
# Feature: empath_vacation_count
# Feature: empath_vacation_ratio
# Feature: empath_dispute_count
# Feature: empath_dispute_ratio
# Feature: empath_nervousness_count
# Feature: empath_nervousness_ratio
# Feature: empath_leisure_count
# Feature: empath_leisure_ratio
# Feature: empath_journalism_count
# Feature: empath_journalism_ratio
# Feature: empath_kill_count
# Feature: empath_kill_ratio
# Feature: empath_play_count
# Feature: empath_play_ratio
# Feature: empath_college_count
# Feature: empath_college_ratio
# Feature: empath_optimism_count
# Feature: empath_optimism_ratio
# Feature: empath_driving_count
# Feature: empath_driving_ratio
# Feature: empath_childish_count
# Feature: empath_childish_ratio
# Feature: empath_internet_count
# Feature: empath_internet_ratio
# Feature: empath_reading_count
# Feature: empath_reading_ratio
# Feature: empath_body_count
# Feature: empath_body_ratio
# Feature: empath_celebration_count
# Feature: empath_celebration_ratio
# Feature: empath_violence_count
# Feature: empath_violence_ratio
# Feature: empath_love_count
# Feature: empath_love_ratio
# Feature: empath_communication_count
# Feature: empath_communication_ratio
# Feature: empath_trust_count
# Feature: empath_trust_ratio
# Feature: empath_deception_count
# Feature: empath_deception_ratio
# Feature: empath_fight_count
# Feature: empath_fight_ratio
# Feature: empath_toy_count
# Feature: empath_toy_ratio
# Feature: empath_war_count
# Feature: empath_war_ratio
# Feature: empath_speaking_count
# Feature: empath_speaking_ratio
# Feature: empath_phone_count
# Feature: empath_phone_ratio
# Feature: empath_science_count
# Feature: empath_science_ratio
# Feature: empath_youth_count
# Feature: empath_youth_ratio
# Feature: empath_fun_count
# Feature: empath_fun_ratio
# Feature: empath_shame_count
# Feature: empath_shame_ratio
# Feature: empath_party_count
# Feature: empath_party_ratio
# Feature: empath_pain_count
# Feature: empath_pain_ratio
# Feature: empath_philosophy_count
# Feature: empath_philosophy_ratio
# Feature: empath_negative_emotion_count
# Feature: empath_negative_emotion_ratio
# Feature: empath_competing_count
# Feature: empath_competing_ratio
# Feature: empath_friends_count
# Feature: empath_friends_ratio
# Feature: empath_weapon_count
# Feature: empath_weapon_ratio
# Feature: empath_children_count
# Feature: empath_children_ratio
# Feature: empath_contentment_count
# Feature: empath_contentment_ratio
# Feature: empath_writing_count
# Feature: empath_writing_ratio
# Feature: empath_help_count
# Feature: empath_help_ratio
# Feature: empath_money_count
# Feature: empath_money_ratio
# Feature: empath_crime_count
# Feature: empath_crime_ratio
# Feature: empath_government_count
# Feature: empath_government_ratio
# Feature: empath_suffering_count
# Feature: empath_suffering_ratio
# Feature: empath_school_count
# Feature: empath_school_ratio
# Feature: empath_magic_count
# Feature: empath_magic_ratio
# Feature: empath_morning_count
# Feature: empath_morning_ratio
# Feature: empath_ridicule_count
# Feature: empath_ridicule_ratio
# Feature: empath_computer_count
# Feature: empath_computer_ratio
# Feature: empath_stealing_count
# Feature: empath_stealing_ratio
# Feature: empath_divine_count
# Feature: empath_divine_ratio
# Feature: empath_business_count
# Feature: empath_business_ratio
# Feature: empath_independence_count
# Feature: empath_independence_ratio
# Feature: empath_movement_count
# Feature: empath_movement_ratio
# Feature: empath_confusion_count
# Feature: empath_confusion_ratio
# Feature: empath_sports_count
# Feature: empath_sports_ratio
# Feature: empath_healing_count
# Feature: empath_healing_ratio
# Feature: empath_legend_count
# Feature: empath_legend_ratio
# Feature: empath_heroic_count
# Feature: empath_heroic_ratio
# Feature: empath_programming_count
# Feature: empath_programming_ratio
# Feature: empath_dominant_personality_count
# Feature: empath_dominant_personality_ratio
# Feature: empath_meeting_count
# Feature: empath_meeting_ratio
# Feature: empath_gain_count
# Feature: empath_gain_ratio
# Feature: empath_injury_count
# Feature: empath_injury_ratio
# Feature: empath_work_count
# Feature: empath_work_ratio
# Feature: empath_valuable_count
# Feature: empath_valuable_ratio
# Feature: empath_sadness_count
# Feature: empath_sadness_ratio
# Feature: empath_traveling_count
# Feature: empath_traveling_ratio
# Feature: empath_strength_count
# Feature: empath_strength_ratio
# Feature: empath_technology_count
# Feature: empath_technology_ratio
# Feature: empath_shape_and_size_count
# Feature: empath_shape_and_size_ratio
# Feature: empath_power_count
# Feature: empath_power_ratio
# Feature: empath_white_collar_job_count
# Feature: empath_white_collar_job_ratio
# Feature: empath_law_count
# Feature: empath_law_ratio
# Feature: empath_giving_count
# Feature: empath_giving_ratio
# Feature: empath_positive_emotion_count
# Feature: empath_positive_emotion_ratio
# Feature: empath_wedding_count
# Feature: empath_wedding_ratio
# Feature: empath_attractive_count
# Feature: empath_attractive_ratio
# Feature: empath_tourism_count
# Feature: empath_tourism_ratio
# Feature: empath_social_media_count
# Feature: empath_social_media_ratio
# Feature: empath_real_estate_count
# Feature: empath_real_estate_ratio
# Feature: empath_hipster_count
# Feature: empath_hipster_ratio
# Feature: empath_hearing_count
# Feature: empath_hearing_ratio
# Feature: empath_weather_count
# Feature: empath_weather_ratio
# Feature: empath_music_count
# Feature: empath_music_ratio
# Feature: empath_listen_count
# Feature: empath_listen_ratio
# Feature: empath_car_count
# Feature: empath_car_ratio
# Feature: empath_messaging_count
# Feature: empath_messaging_ratio
# Feature: empath_achievement_count
# Feature: empath_achievement_ratio
# Feature: empath_rural_count
# Feature: empath_rural_ratio
# Feature: empath_musical_count
# Feature: empath_musical_ratio
# Feature: empath_office_count
# Feature: empath_office_ratio
# Feature: empath_sleep_count
# Feature: empath_sleep_ratio
# Feature: empath_furniture_count
# Feature: empath_furniture_ratio
# Feature: empath_home_count
# Feature: empath_home_ratio
# Feature: empath_military_count
# Feature: empath_military_ratio
# Feature: empath_order_count
# Feature: empath_order_ratio
# Feature: empath_air_travel_count
# Feature: empath_air_travel_ratio
# Feature: empath_emotional_count
# Feature: empath_emotional_ratio
# Feature: empath_politics_count
# Feature: empath_politics_ratio
# Feature: empath_cleaning_count
# Feature: empath_cleaning_ratio
# Feature: empath_hate_count
# Feature: empath_hate_ratio
# Feature: empath_banking_count
# Feature: empath_banking_ratio
# Feature: empath_shopping_count
# Feature: empath_shopping_ratio
# Feature: empath_appearance_count
# Feature: empath_appearance_ratio
# Feature: empath_disappointment_count
# Feature: empath_disappointment_ratio
# Feature: empath_noise_count
# Feature: empath_noise_ratio
# Feature: empath_sound_count
# Feature: empath_sound_ratio
# Feature: empath_alcohol_count
# Feature: empath_alcohol_ratio
# Feature: empath_liquid_count
# Feature: empath_liquid_ratio
# Feature: empath_feminine_count
# Feature: empath_feminine_ratio
# Feature: empath_dance_count
# Feature: empath_dance_ratio
# Feature: empath_family_count
# Feature: empath_family_ratio
# Feature: empath_fear_count
# Feature: empath_fear_ratio
# Feature: empath_vehicle_count
# Feature: empath_vehicle_ratio
# Feature: empath_tool_count
# Feature: empath_tool_ratio
# Feature: empath_economics_count
# Feature: empath_economics_ratio
# Feature: empath_breaking_count
# Feature: empath_breaking_ratio
# Feature: empath_animal_count
# Feature: empath_animal_ratio
# Feature: empath_exercise_count
# Feature: empath_exercise_ratio
# Feature: empath_leader_count
# Feature: empath_leader_ratio
# Feature: empath_restaurant_count
# Feature: empath_restaurant_ratio
# Feature: empath_fabric_count
# Feature: empath_fabric_ratio
# Feature: empath_fire_count
# Feature: empath_fire_ratio
# Feature: empath_warmth_count
# Feature: empath_warmth_ratio
# Feature: empath_clothing_count
# Feature: empath_clothing_ratio
# Feature: empath_fashion_count
# Feature: empath_fashion_ratio
# Feature: empath_domestic_work_count
# Feature: empath_domestic_work_ratio
# Feature: empath_medical_emergency_count
# Feature: empath_medical_emergency_ratio
# Feature: empath_occupation_count
# Feature: empath_occupation_ratio
# Feature: empath_wealthy_count
# Feature: empath_wealthy_ratio
# Feature: empath_blue_collar_job_count
# Feature: empath_blue_collar_job_ratio
# Feature: empath_art_count
# Feature: empath_art_ratio
# Feature: empath_cooking_count
# Feature: empath_cooking_ratio
# Feature: empath_religion_count
# Feature: empath_religion_ratio
# Feature: empath_surprise_count
# Feature: empath_surprise_ratio
# Feature: empath_worship_count
# Feature: empath_worship_ratio
# Feature: empath_eating_count
# Feature: empath_eating_ratio
# Feature: empath_death_count
# Feature: empath_death_ratio
# Feature: empath_dominant_heirarchical_count
# Feature: empath_dominant_heirarchical_ratio
# Feature: empath_neglect_count
# Feature: empath_neglect_ratio
# Feature: empath_hiking_count
# Feature: empath_hiking_ratio
# Feature: empath_farming_count
# Feature: empath_farming_ratio
# Feature: empath_urban_count
# Feature: empath_urban_ratio
# Feature: empath_rage_count
# Feature: empath_rage_ratio
# Feature: empath_torment_count
# Feature: empath_torment_ratio
# Feature: empath_poor_count
# Feature: empath_poor_ratio
# Feature: empath_plant_count
# Feature: empath_plant_ratio
# Feature: empath_beauty_count
# Feature: empath_beauty_ratio
# Feature: empath_negotiate_count
# Feature: empath_negotiate_ratio
# Feature: empath_payment_count
# Feature: empath_payment_ratio
# Feature: empath_cheerfulness_count
# Feature: empath_cheerfulness_ratio
# Feature: empath_masculine_count
# Feature: empath_masculine_ratio
# Feature: empath_prison_count
# Feature: empath_prison_ratio
# Feature: empath_beach_count
# Feature: empath_beach_ratio
# Feature: empath_water_count
# Feature: empath_water_ratio
# Feature: empath_swimming_count
# Feature: empath_swimming_ratio
# Feature: empath_exotic_count
# Feature: empath_exotic_ratio
# Feature: empath_sailing_count
# Feature: empath_sailing_ratio
# Feature: empath_ugliness_count
# Feature: empath_ugliness_ratio
# Feature: empath_ship_count
# Feature: empath_ship_ratio
# Feature: empath_terrorism_count
# Feature: empath_terrorism_ratio
# Feature: empath_monster_count
# Feature: empath_monster_ratio
# Feature: empath_ocean_count
# Feature: empath_ocean_ratio
# Feature: empath_pride_count
# Feature: empath_pride_ratio
# Feature: empath_swearing_terms_count
# Feature: empath_swearing_terms_ratio
# Feature: empath_royalty_count
# Feature: empath_royalty_ratio
# Feature: empath_sexual_count
# Feature: empath_sexual_ratio
# Feature: empath_health_count
# Feature: empath_health_ratio
# Feature: empath_hygiene_count
# Feature: empath_hygiene_ratio
# Feature: empath_pet_count
# Feature: empath_pet_ratio
# Feature: empath_smell_count
# Feature: empath_smell_ratio
# Feature: empath_sympathy_count
# Feature: empath_sympathy_ratio
# Feature: empath_lust_count
# Feature: empath_lust_ratio
# Feature: empath_disgust_count
# Feature: empath_disgust_ratio
# Feature: empath_envy_count
# Feature: empath_envy_ratio
# Feature: empath_night_count
# Feature: empath_night_ratio
# Feature: empath_ancient_count
# Feature: empath_ancient_ratio
# Feature: empath_politeness_count
# Feature: empath_politeness_ratio
# Feature: empath_horror_count
# Feature: empath_horror_ratio
# Feature: empath_timidity_count
# Feature: empath_timidity_ratio
# Feature: empath_weakness_count
# Feature: empath_weakness_ratio
# Feature: empath_zest_count
# Feature: empath_zest_ratio
# Feature: empath_joy_count
# Feature: empath_joy_ratio
# Feature: empath_affection_count
# Feature: empath_affection_ratio
# Feature: empath_irritability_count
# Feature: empath_irritability_ratio
# Feature: empath_exasperation_count
# Feature: empath_exasperation_ratio
# Feature: empath_anger_count
# Feature: empath_anger_ratio
# Feature: empath_medieval_count
# Feature: empath_medieval_ratio
# Feature: empath_anticipation_count
# Feature: empath_anticipation_ratio
# Feature: empath_anonymity_count
# Feature: empath_anonymity_ratio
# Feature: empath_superhero_count
# Feature: empath_superhero_ratio
# The IV has
#  ineffective    37713
# okay            6835
# effective       1722
# provocative      522
# Name: effect, dtype: int64. Excluding ['okay']...
# After exclusion:
#  ineffective    37713
# effective       1722
# provocative      522
# Name: effect, dtype: int64. Excluding ['okay']...
# data has 39957 instances
# bonforrini_threshold:  0.016666666666666666
# there are 37 features.
# Feature: emotion_hartmann_anger
# Feature: emotion_hartmann_anger_count
# Feature: emotion_hartmann_anger_ratio
# Feature: emotion_hartmann_disgust
# Feature: emotion_hartmann_disgust_count
# Feature: emotion_hartmann_disgust_ratio
# Feature: emotion_hartmann_fear
# Feature: emotion_hartmann_fear_count
# Feature: emotion_hartmann_fear_ratio
# Feature: emotion_hartmann_joy
# Feature: emotion_hartmann_joy_count
# Feature: emotion_hartmann_joy_ratio
# Feature: emotion_hartmann_neutral
# Feature: emotion_hartmann_neutral_count
# Feature: emotion_hartmann_neutral_ratio
# Feature: emotion_hartmann_sadness
# Feature: emotion_hartmann_sadness_count
# Feature: emotion_hartmann_sadness_ratio
# Feature: emotion_hartmann_surprise
# Feature: emotion_hartmann_surprise_count
# Feature: emotion_hartmann_surprise_ratio
# Feature: hedge_C_count
# Feature: hedge_C_ratio
# Feature: hedge_E_count
# Feature: hedge_E_ratio
# Feature: hedge_N_count
# Feature: hedge_N_ratio
# Feature: hedge_D_count
# Feature: hedge_D_ratio
# Feature: hedge_I_count
# Feature: hedge_I_ratio
# Feature: toxicity_neutral_count
# Feature: toxicity_neutral_ratio
# Feature: toxicity_neutral
# Feature: toxicity_toxic_count
# Feature: toxicity_toxic_ratio
# Feature: toxicity_toxic

# %%
significance_empath_mpqa_NOOKAY_effects_df
# Out:
#                     effective ineffective  effective provocative  \
# feature
# mpqa_authority                       0.01                    NaN
# mpqa_emphasis                        0.01                    NaN
# mpqa_necessity                       0.02                    NaN
# mpqa_causation                       0.02                    NaN
# mpqa_conditionals                    0.01                    NaN
# mpqa_inconsistency                   0.03                    NaN
# mpqa_possibility                     0.01                    NaN
# mpqa_contrast                        0.02                    NaN
# mpqa_priority                        0.01                    NaN
# mpqa_argumentative                   0.03                    NaN
# mpqa_args_count                      0.03                    NaN
#
#                     ineffective provocative
# feature
# mpqa_authority                          NaN
# mpqa_emphasis                           NaN
# mpqa_necessity                        -0.02
# mpqa_causation                        -0.01
# mpqa_conditionals                       NaN
# mpqa_inconsistency                      NaN
# mpqa_possibility                        NaN
# mpqa_contrast                           NaN
# mpqa_priority                           NaN
# mpqa_argumentative                    -0.01
# mpqa_args_count                       -0.01

# %%
significance_transformers_NOOKAY_effects_df
# Out:
#                                 effective ineffective  effective provocative  \
# feature
# emotion_hartmann_anger                            NaN                  -0.06
# emotion_hartmann_anger_count                     0.02                    NaN
# emotion_hartmann_disgust                         0.02                    NaN
# emotion_hartmann_disgust_count                   0.03                    NaN
# emotion_hartmann_disgust_ratio                   0.02                    NaN
# emotion_hartmann_joy                             0.03                    NaN
# emotion_hartmann_joy_count                       0.03                    NaN
# emotion_hartmann_joy_ratio                       0.02                    NaN
# emotion_hartmann_neutral                         0.02                   0.06
# emotion_hartmann_neutral_count                   0.04                   0.06
# emotion_hartmann_neutral_ratio                   0.01                   0.05
# emotion_hartmann_surprise                         NaN                   0.05
# hedge_C_count                                    0.02                    NaN
# toxicity_neutral_count                           0.04                   0.05
#
#                                 ineffective provocative
# feature
# emotion_hartmann_anger                            -0.01
# emotion_hartmann_anger_count                        NaN
# emotion_hartmann_disgust                          -0.02
# emotion_hartmann_disgust_count                    -0.01
# emotion_hartmann_disgust_ratio                    -0.01
# emotion_hartmann_joy                                NaN
# emotion_hartmann_joy_count                          NaN
# emotion_hartmann_joy_ratio                          NaN
# emotion_hartmann_neutral                            NaN
# emotion_hartmann_neutral_count                      NaN
# emotion_hartmann_neutral_ratio                      NaN
# emotion_hartmann_surprise                          0.02
# hedge_C_count                                     -0.01
# toxicity_neutral_count                              NaN

# %% [markdown]
# ### Binary Effects

# %%
significance_empath_mpqa_binaryeffects_df = iesta.stats.significance.calc_sign_effects(
                        style_features_df, 
                        "liberal", 
                        "empath-mpqa", 
                        "binary_effect", 
                        exclude_iv_vals = [])


significance_transformers_binaryeffects_df = iesta.stats.significance.calc_sign_effects(
                        transformer_features_df, 
                        "liberal", 
                        "transformers", 
                        "binary_effect", 
                        exclude_iv_vals = [])
# Out:
# data has 46792 instances
# bonforrini_threshold:  0.05
# there are 408 features.
# Feature: mpqa_assessments
# Feature: mpqa_doubt
# Feature: mpqa_authority
# Feature: mpqa_emphasis
# Feature: mpqa_necessity
# Feature: mpqa_causation
# Feature: mpqa_generalization
# Feature: mpqa_structure
# Feature: mpqa_conditionals
# Feature: mpqa_inconsistency
# Feature: mpqa_possibility
# Feature: mpqa_wants
# Feature: mpqa_contrast
# Feature: mpqa_priority
# Feature: mpqa_difficulty
# Feature: mpqa_inyourshoes
# Feature: mpqa_rhetoricalquestion
# Feature: mpqa_argumentative
# Feature: mpqa_token_ratio
# Feature: mpqa_args_count
# Feature: empath_cold_count
# Feature: empath_cold_ratio
# Feature: empath_aggression_count
# Feature: empath_aggression_ratio
# Feature: empath_vacation_count
# Feature: empath_vacation_ratio
# Feature: empath_dispute_count
# Feature: empath_dispute_ratio
# Feature: empath_nervousness_count
# Feature: empath_nervousness_ratio
# Feature: empath_leisure_count
# Feature: empath_leisure_ratio
# Feature: empath_journalism_count
# Feature: empath_journalism_ratio
# Feature: empath_kill_count
# Feature: empath_kill_ratio
# Feature: empath_play_count
# Feature: empath_play_ratio
# Feature: empath_college_count
# Feature: empath_college_ratio
# Feature: empath_optimism_count
# Feature: empath_optimism_ratio
# Feature: empath_driving_count
# Feature: empath_driving_ratio
# Feature: empath_childish_count
# Feature: empath_childish_ratio
# Feature: empath_internet_count
# Feature: empath_internet_ratio
# Feature: empath_reading_count
# Feature: empath_reading_ratio
# Feature: empath_body_count
# Feature: empath_body_ratio
# Feature: empath_celebration_count
# Feature: empath_celebration_ratio
# Feature: empath_violence_count
# Feature: empath_violence_ratio
# Feature: empath_love_count
# Feature: empath_love_ratio
# Feature: empath_communication_count
# Feature: empath_communication_ratio
# Feature: empath_trust_count
# Feature: empath_trust_ratio
# Feature: empath_deception_count
# Feature: empath_deception_ratio
# Feature: empath_fight_count
# Feature: empath_fight_ratio
# Feature: empath_toy_count
# Feature: empath_toy_ratio
# Feature: empath_war_count
# Feature: empath_war_ratio
# Feature: empath_speaking_count
# Feature: empath_speaking_ratio
# Feature: empath_phone_count
# Feature: empath_phone_ratio
# Feature: empath_science_count
# Feature: empath_science_ratio
# Feature: empath_youth_count
# Feature: empath_youth_ratio
# Feature: empath_fun_count
# Feature: empath_fun_ratio
# Feature: empath_shame_count
# Feature: empath_shame_ratio
# Feature: empath_party_count
# Feature: empath_party_ratio
# Feature: empath_pain_count
# Feature: empath_pain_ratio
# Feature: empath_philosophy_count
# Feature: empath_philosophy_ratio
# Feature: empath_negative_emotion_count
# Feature: empath_negative_emotion_ratio
# Feature: empath_competing_count
# Feature: empath_competing_ratio
# Feature: empath_friends_count
# Feature: empath_friends_ratio
# Feature: empath_weapon_count
# Feature: empath_weapon_ratio
# Feature: empath_children_count
# Feature: empath_children_ratio
# Feature: empath_contentment_count
# Feature: empath_contentment_ratio
# Feature: empath_writing_count
# Feature: empath_writing_ratio
# Feature: empath_help_count
# Feature: empath_help_ratio
# Feature: empath_money_count
# Feature: empath_money_ratio
# Feature: empath_crime_count
# Feature: empath_crime_ratio
# Feature: empath_government_count
# Feature: empath_government_ratio
# Feature: empath_suffering_count
# Feature: empath_suffering_ratio
# Feature: empath_school_count
# Feature: empath_school_ratio
# Feature: empath_magic_count
# Feature: empath_magic_ratio
# Feature: empath_morning_count
# Feature: empath_morning_ratio
# Feature: empath_ridicule_count
# Feature: empath_ridicule_ratio
# Feature: empath_computer_count
# Feature: empath_computer_ratio
# Feature: empath_stealing_count
# Feature: empath_stealing_ratio
# Feature: empath_divine_count
# Feature: empath_divine_ratio
# Feature: empath_business_count
# Feature: empath_business_ratio
# Feature: empath_independence_count
# Feature: empath_independence_ratio
# Feature: empath_movement_count
# Feature: empath_movement_ratio
# Feature: empath_confusion_count
# Feature: empath_confusion_ratio
# Feature: empath_sports_count
# Feature: empath_sports_ratio
# Feature: empath_healing_count
# Feature: empath_healing_ratio
# Feature: empath_legend_count
# Feature: empath_legend_ratio
# Feature: empath_heroic_count
# Feature: empath_heroic_ratio
# Feature: empath_programming_count
# Feature: empath_programming_ratio
# Feature: empath_dominant_personality_count
# Feature: empath_dominant_personality_ratio
# Feature: empath_meeting_count
# Feature: empath_meeting_ratio
# Feature: empath_gain_count
# Feature: empath_gain_ratio
# Feature: empath_injury_count
# Feature: empath_injury_ratio
# Feature: empath_work_count
# Feature: empath_work_ratio
# Feature: empath_valuable_count
# Feature: empath_valuable_ratio
# Feature: empath_sadness_count
# Feature: empath_sadness_ratio
# Feature: empath_traveling_count
# Feature: empath_traveling_ratio
# Feature: empath_strength_count
# Feature: empath_strength_ratio
# Feature: empath_technology_count
# Feature: empath_technology_ratio
# Feature: empath_shape_and_size_count
# Feature: empath_shape_and_size_ratio
# Feature: empath_power_count
# Feature: empath_power_ratio
# Feature: empath_white_collar_job_count
# Feature: empath_white_collar_job_ratio
# Feature: empath_law_count
# Feature: empath_law_ratio
# Feature: empath_giving_count
# Feature: empath_giving_ratio
# Feature: empath_positive_emotion_count
# Feature: empath_positive_emotion_ratio
# Feature: empath_wedding_count
# Feature: empath_wedding_ratio
# Feature: empath_attractive_count
# Feature: empath_attractive_ratio
# Feature: empath_tourism_count
# Feature: empath_tourism_ratio
# Feature: empath_social_media_count
# Feature: empath_social_media_ratio
# Feature: empath_real_estate_count
# Feature: empath_real_estate_ratio
# Feature: empath_hipster_count
# Feature: empath_hipster_ratio
# Feature: empath_hearing_count
# Feature: empath_hearing_ratio
# Feature: empath_weather_count
# Feature: empath_weather_ratio
# Feature: empath_music_count
# Feature: empath_music_ratio
# Feature: empath_listen_count
# Feature: empath_listen_ratio
# Feature: empath_car_count
# Feature: empath_car_ratio
# Feature: empath_messaging_count
# Feature: empath_messaging_ratio
# Feature: empath_achievement_count
# Feature: empath_achievement_ratio
# Feature: empath_rural_count
# Feature: empath_rural_ratio
# Feature: empath_musical_count
# Feature: empath_musical_ratio
# Feature: empath_office_count
# Feature: empath_office_ratio
# Feature: empath_sleep_count
# Feature: empath_sleep_ratio
# Feature: empath_furniture_count
# Feature: empath_furniture_ratio
# Feature: empath_home_count
# Feature: empath_home_ratio
# Feature: empath_military_count
# Feature: empath_military_ratio
# Feature: empath_order_count
# Feature: empath_order_ratio
# Feature: empath_air_travel_count
# Feature: empath_air_travel_ratio
# Feature: empath_emotional_count
# Feature: empath_emotional_ratio
# Feature: empath_politics_count
# Feature: empath_politics_ratio
# Feature: empath_cleaning_count
# Feature: empath_cleaning_ratio
# Feature: empath_hate_count
# Feature: empath_hate_ratio
# Feature: empath_banking_count
# Feature: empath_banking_ratio
# Feature: empath_shopping_count
# Feature: empath_shopping_ratio
# Feature: empath_appearance_count
# Feature: empath_appearance_ratio
# Feature: empath_disappointment_count
# Feature: empath_disappointment_ratio
# Feature: empath_noise_count
# Feature: empath_noise_ratio
# Feature: empath_sound_count
# Feature: empath_sound_ratio
# Feature: empath_alcohol_count
# Feature: empath_alcohol_ratio
# Feature: empath_liquid_count
# Feature: empath_liquid_ratio
# Feature: empath_feminine_count
# Feature: empath_feminine_ratio
# Feature: empath_dance_count
# Feature: empath_dance_ratio
# Feature: empath_family_count
# Feature: empath_family_ratio
# Feature: empath_fear_count
# Feature: empath_fear_ratio
# Feature: empath_vehicle_count
# Feature: empath_vehicle_ratio
# Feature: empath_tool_count
# Feature: empath_tool_ratio
# Feature: empath_economics_count
# Feature: empath_economics_ratio
# Feature: empath_breaking_count
# Feature: empath_breaking_ratio
# Feature: empath_animal_count
# Feature: empath_animal_ratio
# Feature: empath_exercise_count
# Feature: empath_exercise_ratio
# Feature: empath_leader_count
# Feature: empath_leader_ratio
# Feature: empath_restaurant_count
# Feature: empath_restaurant_ratio
# Feature: empath_fabric_count
# Feature: empath_fabric_ratio
# Feature: empath_fire_count
# Feature: empath_fire_ratio
# Feature: empath_warmth_count
# Feature: empath_warmth_ratio
# Feature: empath_clothing_count
# Feature: empath_clothing_ratio
# Feature: empath_fashion_count
# Feature: empath_fashion_ratio
# Feature: empath_domestic_work_count
# Feature: empath_domestic_work_ratio
# Feature: empath_medical_emergency_count
# Feature: empath_medical_emergency_ratio
# Feature: empath_occupation_count
# Feature: empath_occupation_ratio
# Feature: empath_wealthy_count
# Feature: empath_wealthy_ratio
# Feature: empath_blue_collar_job_count
# Feature: empath_blue_collar_job_ratio
# Feature: empath_art_count
# Feature: empath_art_ratio
# Feature: empath_cooking_count
# Feature: empath_cooking_ratio
# Feature: empath_religion_count
# Feature: empath_religion_ratio
# Feature: empath_surprise_count
# Feature: empath_surprise_ratio
# Feature: empath_worship_count
# Feature: empath_worship_ratio
# Feature: empath_eating_count
# Feature: empath_eating_ratio
# Feature: empath_death_count
# Feature: empath_death_ratio
# Feature: empath_dominant_heirarchical_count
# Feature: empath_dominant_heirarchical_ratio
# Feature: empath_neglect_count
# Feature: empath_neglect_ratio
# Feature: empath_hiking_count
# Feature: empath_hiking_ratio
# Feature: empath_farming_count
# Feature: empath_farming_ratio
# Feature: empath_urban_count
# Feature: empath_urban_ratio
# Feature: empath_rage_count
# Feature: empath_rage_ratio
# Feature: empath_torment_count
# Feature: empath_torment_ratio
# Feature: empath_poor_count
# Feature: empath_poor_ratio
# Feature: empath_plant_count
# Feature: empath_plant_ratio
# Feature: empath_beauty_count
# Feature: empath_beauty_ratio
# Feature: empath_negotiate_count
# Feature: empath_negotiate_ratio
# Feature: empath_payment_count
# Feature: empath_payment_ratio
# Feature: empath_cheerfulness_count
# Feature: empath_cheerfulness_ratio
# Feature: empath_masculine_count
# Feature: empath_masculine_ratio
# Feature: empath_prison_count
# Feature: empath_prison_ratio
# Feature: empath_beach_count
# Feature: empath_beach_ratio
# Feature: empath_water_count
# Feature: empath_water_ratio
# Feature: empath_swimming_count
# Feature: empath_swimming_ratio
# Feature: empath_exotic_count
# Feature: empath_exotic_ratio
# Feature: empath_sailing_count
# Feature: empath_sailing_ratio
# Feature: empath_ugliness_count
# Feature: empath_ugliness_ratio
# Feature: empath_ship_count
# Feature: empath_ship_ratio
# Feature: empath_terrorism_count
# Feature: empath_terrorism_ratio
# Feature: empath_monster_count
# Feature: empath_monster_ratio
# Feature: empath_ocean_count
# Feature: empath_ocean_ratio
# Feature: empath_pride_count
# Feature: empath_pride_ratio
# Feature: empath_swearing_terms_count
# Feature: empath_swearing_terms_ratio
# Feature: empath_royalty_count
# Feature: empath_royalty_ratio
# Feature: empath_sexual_count
# Feature: empath_sexual_ratio
# Feature: empath_health_count
# Feature: empath_health_ratio
# Feature: empath_hygiene_count
# Feature: empath_hygiene_ratio
# Feature: empath_pet_count
# Feature: empath_pet_ratio
# Feature: empath_smell_count
# Feature: empath_smell_ratio
# Feature: empath_sympathy_count
# Feature: empath_sympathy_ratio
# Feature: empath_lust_count
# Feature: empath_lust_ratio
# Feature: empath_disgust_count
# Feature: empath_disgust_ratio
# Feature: empath_envy_count
# Feature: empath_envy_ratio
# Feature: empath_night_count
# Feature: empath_night_ratio
# Feature: empath_ancient_count
# Feature: empath_ancient_ratio
# Feature: empath_politeness_count
# Feature: empath_politeness_ratio
# Feature: empath_horror_count
# Feature: empath_horror_ratio
# Feature: empath_timidity_count
# Feature: empath_timidity_ratio
# Feature: empath_weakness_count
# Feature: empath_weakness_ratio
# Feature: empath_zest_count
# Feature: empath_zest_ratio
# Feature: empath_joy_count
# Feature: empath_joy_ratio
# Feature: empath_affection_count
# Feature: empath_affection_ratio
# Feature: empath_irritability_count
# Feature: empath_irritability_ratio
# Feature: empath_exasperation_count
# Feature: empath_exasperation_ratio
# Feature: empath_anger_count
# Feature: empath_anger_ratio
# Feature: empath_medieval_count
# Feature: empath_medieval_ratio
# Feature: empath_anticipation_count
# Feature: empath_anticipation_ratio
# Feature: empath_anonymity_count
# Feature: empath_anonymity_ratio
# Feature: empath_superhero_count
# Feature: empath_superhero_ratio
# data has 46792 instances
# bonforrini_threshold:  0.05
# there are 37 features.
# Feature: emotion_hartmann_anger
# Feature: emotion_hartmann_anger_count
# Feature: emotion_hartmann_anger_ratio
# Feature: emotion_hartmann_disgust
# Feature: emotion_hartmann_disgust_count
# Feature: emotion_hartmann_disgust_ratio
# Feature: emotion_hartmann_fear
# Feature: emotion_hartmann_fear_count
# Feature: emotion_hartmann_fear_ratio
# Feature: emotion_hartmann_joy
# Feature: emotion_hartmann_joy_count
# Feature: emotion_hartmann_joy_ratio
# Feature: emotion_hartmann_neutral
# Feature: emotion_hartmann_neutral_count
# Feature: emotion_hartmann_neutral_ratio
# Feature: emotion_hartmann_sadness
# Feature: emotion_hartmann_sadness_count
# Feature: emotion_hartmann_sadness_ratio
# Feature: emotion_hartmann_surprise
# Feature: emotion_hartmann_surprise_count
# Feature: emotion_hartmann_surprise_ratio
# Feature: hedge_C_count
# Feature: hedge_C_ratio
# Feature: hedge_E_count
# Feature: hedge_E_ratio
# Feature: hedge_N_count
# Feature: hedge_N_ratio
# Feature: hedge_D_count
# Feature: hedge_D_ratio
# Feature: hedge_I_count
# Feature: hedge_I_ratio
# Feature: toxicity_neutral_count
# Feature: toxicity_neutral_ratio
# Feature: toxicity_neutral
# Feature: toxicity_toxic_count
# Feature: toxicity_toxic_ratio
# Feature: toxicity_toxic

# %%
significance_empath_mpqa_binaryeffects_df
# Out:
#                     effective ineffective
# feature
# mpqa_authority                       0.01
# mpqa_emphasis                        0.01
# mpqa_necessity                       0.02
# mpqa_causation                       0.02
# mpqa_conditionals                    0.01
# mpqa_inconsistency                   0.02
# mpqa_possibility                     0.01
# mpqa_contrast                        0.01
# mpqa_priority                        0.01
# mpqa_argumentative                   0.02
# mpqa_args_count                      0.02

# %%
significance_transformers_binaryeffects_df
# Out:
#                                 effective ineffective
# feature
# emotion_hartmann_anger_count                     0.01
# emotion_hartmann_disgust                         0.01
# emotion_hartmann_disgust_count                   0.02
# emotion_hartmann_disgust_ratio                   0.01
# emotion_hartmann_joy                             0.03
# emotion_hartmann_joy_count                       0.02
# emotion_hartmann_joy_ratio                       0.02
# emotion_hartmann_neutral                         0.01
# emotion_hartmann_neutral_count                   0.03
# emotion_hartmann_neutral_ratio                   0.01
# hedge_C_count                                    0.01
# toxicity_neutral_count                           0.03

# %% [markdown]
# ### Binary Effects - Excluding *Okay*

# %%
significance_empath_mpqa_NOOKAY_binaryeffects_df = iesta.stats.significance.calc_sign_effects(
                        style_features_df[style_features_df["effect"] != "okay"], 
                        "liberal", 
                        "empath-mpqa", 
                        "binary_effect", 
                        exclude_iv_vals = [])

significance_transformers_NOOKAY_binaryeffects_df = iesta.stats.significance.calc_sign_effects(
                        transformer_features_df[transformer_features_df["effect"] != "okay"], 
                        "liberal", 
                        "transformers", 
                        "binary_effect", 
                        exclude_iv_vals = [])
# Out:
# data has 39957 instances
# bonforrini_threshold:  0.05
# there are 408 features.
# Feature: mpqa_assessments
# Feature: mpqa_doubt
# Feature: mpqa_authority
# Feature: mpqa_emphasis
# Feature: mpqa_necessity
# Feature: mpqa_causation
# Feature: mpqa_generalization
# Feature: mpqa_structure
# Feature: mpqa_conditionals
# Feature: mpqa_inconsistency
# Feature: mpqa_possibility
# Feature: mpqa_wants
# Feature: mpqa_contrast
# Feature: mpqa_priority
# Feature: mpqa_difficulty
# Feature: mpqa_inyourshoes
# Feature: mpqa_rhetoricalquestion
# Feature: mpqa_argumentative
# Feature: mpqa_token_ratio
# Feature: mpqa_args_count
# Feature: empath_cold_count
# Feature: empath_cold_ratio
# Feature: empath_aggression_count
# Feature: empath_aggression_ratio
# Feature: empath_vacation_count
# Feature: empath_vacation_ratio
# Feature: empath_dispute_count
# Feature: empath_dispute_ratio
# Feature: empath_nervousness_count
# Feature: empath_nervousness_ratio
# Feature: empath_leisure_count
# Feature: empath_leisure_ratio
# Feature: empath_journalism_count
# Feature: empath_journalism_ratio
# Feature: empath_kill_count
# Feature: empath_kill_ratio
# Feature: empath_play_count
# Feature: empath_play_ratio
# Feature: empath_college_count
# Feature: empath_college_ratio
# Feature: empath_optimism_count
# Feature: empath_optimism_ratio
# Feature: empath_driving_count
# Feature: empath_driving_ratio
# Feature: empath_childish_count
# Feature: empath_childish_ratio
# Feature: empath_internet_count
# Feature: empath_internet_ratio
# Feature: empath_reading_count
# Feature: empath_reading_ratio
# Feature: empath_body_count
# Feature: empath_body_ratio
# Feature: empath_celebration_count
# Feature: empath_celebration_ratio
# Feature: empath_violence_count
# Feature: empath_violence_ratio
# Feature: empath_love_count
# Feature: empath_love_ratio
# Feature: empath_communication_count
# Feature: empath_communication_ratio
# Feature: empath_trust_count
# Feature: empath_trust_ratio
# Feature: empath_deception_count
# Feature: empath_deception_ratio
# Feature: empath_fight_count
# Feature: empath_fight_ratio
# Feature: empath_toy_count
# Feature: empath_toy_ratio
# Feature: empath_war_count
# Feature: empath_war_ratio
# Feature: empath_speaking_count
# Feature: empath_speaking_ratio
# Feature: empath_phone_count
# Feature: empath_phone_ratio
# Feature: empath_science_count
# Feature: empath_science_ratio
# Feature: empath_youth_count
# Feature: empath_youth_ratio
# Feature: empath_fun_count
# Feature: empath_fun_ratio
# Feature: empath_shame_count
# Feature: empath_shame_ratio
# Feature: empath_party_count
# Feature: empath_party_ratio
# Feature: empath_pain_count
# Feature: empath_pain_ratio
# Feature: empath_philosophy_count
# Feature: empath_philosophy_ratio
# Feature: empath_negative_emotion_count
# Feature: empath_negative_emotion_ratio
# Feature: empath_competing_count
# Feature: empath_competing_ratio
# Feature: empath_friends_count
# Feature: empath_friends_ratio
# Feature: empath_weapon_count
# Feature: empath_weapon_ratio
# Feature: empath_children_count
# Feature: empath_children_ratio
# Feature: empath_contentment_count
# Feature: empath_contentment_ratio
# Feature: empath_writing_count
# Feature: empath_writing_ratio
# Feature: empath_help_count
# Feature: empath_help_ratio
# Feature: empath_money_count
# Feature: empath_money_ratio
# Feature: empath_crime_count
# Feature: empath_crime_ratio
# Feature: empath_government_count
# Feature: empath_government_ratio
# Feature: empath_suffering_count
# Feature: empath_suffering_ratio
# Feature: empath_school_count
# Feature: empath_school_ratio
# Feature: empath_magic_count
# Feature: empath_magic_ratio
# Feature: empath_morning_count
# Feature: empath_morning_ratio
# Feature: empath_ridicule_count
# Feature: empath_ridicule_ratio
# Feature: empath_computer_count
# Feature: empath_computer_ratio
# Feature: empath_stealing_count
# Feature: empath_stealing_ratio
# Feature: empath_divine_count
# Feature: empath_divine_ratio
# Feature: empath_business_count
# Feature: empath_business_ratio
# Feature: empath_independence_count
# Feature: empath_independence_ratio
# Feature: empath_movement_count
# Feature: empath_movement_ratio
# Feature: empath_confusion_count
# Feature: empath_confusion_ratio
# Feature: empath_sports_count
# Feature: empath_sports_ratio
# Feature: empath_healing_count
# Feature: empath_healing_ratio
# Feature: empath_legend_count
# Feature: empath_legend_ratio
# Feature: empath_heroic_count
# Feature: empath_heroic_ratio
# Feature: empath_programming_count
# Feature: empath_programming_ratio
# Feature: empath_dominant_personality_count
# Feature: empath_dominant_personality_ratio
# Feature: empath_meeting_count
# Feature: empath_meeting_ratio
# Feature: empath_gain_count
# Feature: empath_gain_ratio
# Feature: empath_injury_count
# Feature: empath_injury_ratio
# Feature: empath_work_count
# Feature: empath_work_ratio
# Feature: empath_valuable_count
# Feature: empath_valuable_ratio
# Feature: empath_sadness_count
# Feature: empath_sadness_ratio
# Feature: empath_traveling_count
# Feature: empath_traveling_ratio
# Feature: empath_strength_count
# Feature: empath_strength_ratio
# Feature: empath_technology_count
# Feature: empath_technology_ratio
# Feature: empath_shape_and_size_count
# Feature: empath_shape_and_size_ratio
# Feature: empath_power_count
# Feature: empath_power_ratio
# Feature: empath_white_collar_job_count
# Feature: empath_white_collar_job_ratio
# Feature: empath_law_count
# Feature: empath_law_ratio
# Feature: empath_giving_count
# Feature: empath_giving_ratio
# Feature: empath_positive_emotion_count
# Feature: empath_positive_emotion_ratio
# Feature: empath_wedding_count
# Feature: empath_wedding_ratio
# Feature: empath_attractive_count
# Feature: empath_attractive_ratio
# Feature: empath_tourism_count
# Feature: empath_tourism_ratio
# Feature: empath_social_media_count
# Feature: empath_social_media_ratio
# Feature: empath_real_estate_count
# Feature: empath_real_estate_ratio
# Feature: empath_hipster_count
# Feature: empath_hipster_ratio
# Feature: empath_hearing_count
# Feature: empath_hearing_ratio
# Feature: empath_weather_count
# Feature: empath_weather_ratio
# Feature: empath_music_count
# Feature: empath_music_ratio
# Feature: empath_listen_count
# Feature: empath_listen_ratio
# Feature: empath_car_count
# Feature: empath_car_ratio
# Feature: empath_messaging_count
# Feature: empath_messaging_ratio
# Feature: empath_achievement_count
# Feature: empath_achievement_ratio
# Feature: empath_rural_count
# Feature: empath_rural_ratio
# Feature: empath_musical_count
# Feature: empath_musical_ratio
# Feature: empath_office_count
# Feature: empath_office_ratio
# Feature: empath_sleep_count
# Feature: empath_sleep_ratio
# Feature: empath_furniture_count
# Feature: empath_furniture_ratio
# Feature: empath_home_count
# Feature: empath_home_ratio
# Feature: empath_military_count
# Feature: empath_military_ratio
# Feature: empath_order_count
# Feature: empath_order_ratio
# Feature: empath_air_travel_count
# Feature: empath_air_travel_ratio
# Feature: empath_emotional_count
# Feature: empath_emotional_ratio
# Feature: empath_politics_count
# Feature: empath_politics_ratio
# Feature: empath_cleaning_count
# Feature: empath_cleaning_ratio
# Feature: empath_hate_count
# Feature: empath_hate_ratio
# Feature: empath_banking_count
# Feature: empath_banking_ratio
# Feature: empath_shopping_count
# Feature: empath_shopping_ratio
# Feature: empath_appearance_count
# Feature: empath_appearance_ratio
# Feature: empath_disappointment_count
# Feature: empath_disappointment_ratio
# Feature: empath_noise_count
# Feature: empath_noise_ratio
# Feature: empath_sound_count
# Feature: empath_sound_ratio
# Feature: empath_alcohol_count
# Feature: empath_alcohol_ratio
# Feature: empath_liquid_count
# Feature: empath_liquid_ratio
# Feature: empath_feminine_count
# Feature: empath_feminine_ratio
# Feature: empath_dance_count
# Feature: empath_dance_ratio
# Feature: empath_family_count
# Feature: empath_family_ratio
# Feature: empath_fear_count
# Feature: empath_fear_ratio
# Feature: empath_vehicle_count
# Feature: empath_vehicle_ratio
# Feature: empath_tool_count
# Feature: empath_tool_ratio
# Feature: empath_economics_count
# Feature: empath_economics_ratio
# Feature: empath_breaking_count
# Feature: empath_breaking_ratio
# Feature: empath_animal_count
# Feature: empath_animal_ratio
# Feature: empath_exercise_count
# Feature: empath_exercise_ratio
# Feature: empath_leader_count
# Feature: empath_leader_ratio
# Feature: empath_restaurant_count
# Feature: empath_restaurant_ratio
# Feature: empath_fabric_count
# Feature: empath_fabric_ratio
# Feature: empath_fire_count
# Feature: empath_fire_ratio
# Feature: empath_warmth_count
# Feature: empath_warmth_ratio
# Feature: empath_clothing_count
# Feature: empath_clothing_ratio
# Feature: empath_fashion_count
# Feature: empath_fashion_ratio
# Feature: empath_domestic_work_count
# Feature: empath_domestic_work_ratio
# Feature: empath_medical_emergency_count
# Feature: empath_medical_emergency_ratio
# Feature: empath_occupation_count
# Feature: empath_occupation_ratio
# Feature: empath_wealthy_count
# Feature: empath_wealthy_ratio
# Feature: empath_blue_collar_job_count
# Feature: empath_blue_collar_job_ratio
# Feature: empath_art_count
# Feature: empath_art_ratio
# Feature: empath_cooking_count
# Feature: empath_cooking_ratio
# Feature: empath_religion_count
# Feature: empath_religion_ratio
# Feature: empath_surprise_count
# Feature: empath_surprise_ratio
# Feature: empath_worship_count
# Feature: empath_worship_ratio
# Feature: empath_eating_count
# Feature: empath_eating_ratio
# Feature: empath_death_count
# Feature: empath_death_ratio
# Feature: empath_dominant_heirarchical_count
# Feature: empath_dominant_heirarchical_ratio
# Feature: empath_neglect_count
# Feature: empath_neglect_ratio
# Feature: empath_hiking_count
# Feature: empath_hiking_ratio
# Feature: empath_farming_count
# Feature: empath_farming_ratio
# Feature: empath_urban_count
# Feature: empath_urban_ratio
# Feature: empath_rage_count
# Feature: empath_rage_ratio
# Feature: empath_torment_count
# Feature: empath_torment_ratio
# Feature: empath_poor_count
# Feature: empath_poor_ratio
# Feature: empath_plant_count
# Feature: empath_plant_ratio
# Feature: empath_beauty_count
# Feature: empath_beauty_ratio
# Feature: empath_negotiate_count
# Feature: empath_negotiate_ratio
# Feature: empath_payment_count
# Feature: empath_payment_ratio
# Feature: empath_cheerfulness_count
# Feature: empath_cheerfulness_ratio
# Feature: empath_masculine_count
# Feature: empath_masculine_ratio
# Feature: empath_prison_count
# Feature: empath_prison_ratio
# Feature: empath_beach_count
# Feature: empath_beach_ratio
# Feature: empath_water_count
# Feature: empath_water_ratio
# Feature: empath_swimming_count
# Feature: empath_swimming_ratio
# Feature: empath_exotic_count
# Feature: empath_exotic_ratio
# Feature: empath_sailing_count
# Feature: empath_sailing_ratio
# Feature: empath_ugliness_count
# Feature: empath_ugliness_ratio
# Feature: empath_ship_count
# Feature: empath_ship_ratio
# Feature: empath_terrorism_count
# Feature: empath_terrorism_ratio
# Feature: empath_monster_count
# Feature: empath_monster_ratio
# Feature: empath_ocean_count
# Feature: empath_ocean_ratio
# Feature: empath_pride_count
# Feature: empath_pride_ratio
# Feature: empath_swearing_terms_count
# Feature: empath_swearing_terms_ratio
# Feature: empath_royalty_count
# Feature: empath_royalty_ratio
# Feature: empath_sexual_count
# Feature: empath_sexual_ratio
# Feature: empath_health_count
# Feature: empath_health_ratio
# Feature: empath_hygiene_count
# Feature: empath_hygiene_ratio
# Feature: empath_pet_count
# Feature: empath_pet_ratio
# Feature: empath_smell_count
# Feature: empath_smell_ratio
# Feature: empath_sympathy_count
# Feature: empath_sympathy_ratio
# Feature: empath_lust_count
# Feature: empath_lust_ratio
# Feature: empath_disgust_count
# Feature: empath_disgust_ratio
# Feature: empath_envy_count
# Feature: empath_envy_ratio
# Feature: empath_night_count
# Feature: empath_night_ratio
# Feature: empath_ancient_count
# Feature: empath_ancient_ratio
# Feature: empath_politeness_count
# Feature: empath_politeness_ratio
# Feature: empath_horror_count
# Feature: empath_horror_ratio
# Feature: empath_timidity_count
# Feature: empath_timidity_ratio
# Feature: empath_weakness_count
# Feature: empath_weakness_ratio
# Feature: empath_zest_count
# Feature: empath_zest_ratio
# Feature: empath_joy_count
# Feature: empath_joy_ratio
# Feature: empath_affection_count
# Feature: empath_affection_ratio
# Feature: empath_irritability_count
# Feature: empath_irritability_ratio
# Feature: empath_exasperation_count
# Feature: empath_exasperation_ratio
# Feature: empath_anger_count
# Feature: empath_anger_ratio
# Feature: empath_medieval_count
# Feature: empath_medieval_ratio
# Feature: empath_anticipation_count
# Feature: empath_anticipation_ratio
# Feature: empath_anonymity_count
# Feature: empath_anonymity_ratio
# Feature: empath_superhero_count
# Feature: empath_superhero_ratio
# data has 39957 instances
# bonforrini_threshold:  0.05
# there are 37 features.
# Feature: emotion_hartmann_anger
# Feature: emotion_hartmann_anger_count
# Feature: emotion_hartmann_anger_ratio
# Feature: emotion_hartmann_disgust
# Feature: emotion_hartmann_disgust_count
# Feature: emotion_hartmann_disgust_ratio
# Feature: emotion_hartmann_fear
# Feature: emotion_hartmann_fear_count
# Feature: emotion_hartmann_fear_ratio
# Feature: emotion_hartmann_joy
# Feature: emotion_hartmann_joy_count
# Feature: emotion_hartmann_joy_ratio
# Feature: emotion_hartmann_neutral
# Feature: emotion_hartmann_neutral_count
# Feature: emotion_hartmann_neutral_ratio
# Feature: emotion_hartmann_sadness
# Feature: emotion_hartmann_sadness_count
# Feature: emotion_hartmann_sadness_ratio
# Feature: emotion_hartmann_surprise
# Feature: emotion_hartmann_surprise_count
# Feature: emotion_hartmann_surprise_ratio
# Feature: hedge_C_count
# Feature: hedge_C_ratio
# Feature: hedge_E_count
# Feature: hedge_E_ratio
# Feature: hedge_N_count
# Feature: hedge_N_ratio
# Feature: hedge_D_count
# Feature: hedge_D_ratio
# Feature: hedge_I_count
# Feature: hedge_I_ratio
# Feature: toxicity_neutral_count
# Feature: toxicity_neutral_ratio
# Feature: toxicity_neutral
# Feature: toxicity_toxic_count
# Feature: toxicity_toxic_ratio
# Feature: toxicity_toxic

# %%
significance_empath_mpqa_NOOKAY_binaryeffects_df
# Out:
#                     effective ineffective
# feature
# mpqa_authority                       0.01
# mpqa_emphasis                        0.01
# mpqa_necessity                       0.02
# mpqa_causation                       0.02
# mpqa_structure                       0.01
# mpqa_conditionals                    0.01
# mpqa_inconsistency                   0.02
# mpqa_possibility                     0.01
# mpqa_contrast                        0.02
# mpqa_priority                        0.01
# mpqa_argumentative                   0.03
# mpqa_args_count                      0.03

# %%
significance_transformers_NOOKAY_binaryeffects_df
# Out:
#                                 effective ineffective
# feature
# emotion_hartmann_anger_count                     0.02
# emotion_hartmann_disgust                         0.02
# emotion_hartmann_disgust_count                   0.03
# emotion_hartmann_disgust_ratio                   0.02
# emotion_hartmann_joy                             0.03
# emotion_hartmann_joy_count                       0.03
# emotion_hartmann_joy_ratio                       0.02
# emotion_hartmann_neutral                         0.02
# emotion_hartmann_neutral_count                   0.04
# emotion_hartmann_neutral_ratio                   0.01
# hedge_C_count                                    0.02
# toxicity_neutral_count                           0.04

# %%
import imblearn

def undersample(df, strategy='.5'):
    col=df.columns
    features=col.tolist() 
    feature=features[:-1] 
    target=features[-1]
    X=df.loc[:,feature]  
    y=df.loc[:,target]
    
    undersample = imblearn.under_sampling.RandomUnderSampler(random_state=0)#, sampling_strategy=strategy)
    X_under, y_under = undersample.fit_resample(X, y)
    print(Counter(y_under))
    return pd.concat([X_under,y_under],axis=1)
