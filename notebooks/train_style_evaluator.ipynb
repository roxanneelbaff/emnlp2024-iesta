# %%
# Import necessary libraries
from datasets import load_dataset
import numpy as np
from sklearn.metrics import f1_score


from iesta.data.iesta_data import IESTAData, LABELS
from iesta.data.huggingface_loader import IESTAHuggingFace

import os

os.environ["HUGGING_FACE_HUB_TOKEN"] = "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"

# %%
def get_data(ideology: str):
    data_object = IESTAData(
        ideology=ideology, keep_labels=LABELS.EFF_INEFF
    )
    huggingface_dataset = IESTAHuggingFace(data_object)

    dataset_name = huggingface_dataset.get_dataset_name(
        is_for_style_classifier=True
    )
    assert f"notaphoenix/debateorg_w_effect_for_{ideology}_subset" == dataset_name
    return load_dataset(dataset_name, split='test')

# %%
# Load the test dataset
# Replace 'your_dataset_name' with the actual dataset name

# %%
def get_random(ideology):
    dataset = load_dataset(f"notaphoenix/debateorg_w_effect_for_{ideology}_subset", use_auth_token=True, split="test")
    seeds = [93213, 60507, 1080, 87035, 69296,86631, 1764, 96728, 19548, 5594]
    random_results = []
    for seed in seeds:
        np.random.seed(seed)
        # Generate random predictions
        # Modify the range of np.random.randint if your dataset has more than two classes
        random_predictions = np.random.randint(2, size=len(dataset), )

        # Extract the true labels
        # Ensure 'label' matches the label field in your dataset
        true_labels = [example['label'] for example in dataset]

        # Calculate and print the Macro F1 Score
        macro_f1 = f1_score(true_labels, random_predictions, average='macro')
        print("Macro F1 Score:", round(macro_f1, 2))
        random_results.append(macro_f1)
    return random_results

# %%
np.array(random_results).mean()

# %%
liberal_random = get_random("liberal")
conservative_random = get_random("conservative")

# %%
len(conservative_random)

# %%
from scipy import stats
liberal_lf = [0.49, 0.59, 0.60, 0.59, 0.60, 0.53, 0.57, 0.57, 0.58, 0.57]
conservative_lf = [0.5, 0.56, 0.58, 0.57, 0.59, 0.55, 0.52, 0.54,0.53, 0.58]
# Example data
random_scores = np.array(conservative_random)  # Replace with your random model scores
fine_tuned_scores = np.array(conservative_lf)  # Replace with your fine-tuned model scores

# Wilcoxon signed-rank test
stat, p = stats.wilcoxon(random_scores, fine_tuned_scores)
print(f"Wilcoxon signed-rank test: Statistic={stat}, P-value={p}")

# Effect Size (Cohen's d)
mean_difference = np.mean(fine_tuned_scores - random_scores)
pooled_std_dev = np.sqrt((np.std(random_scores, ddof=1)**2 + np.std(fine_tuned_scores, ddof=1)**2) / 2)
cohen_d = mean_difference / pooled_std_dev
print(f"Effect Size (Cohen's d): {cohen_d}")

# %%
import openai
from datasets import load_dataset
from sklearn.metrics import f1_score
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
# Load the test dataset
from langchain import PromptTemplate, LLMChain


# OpenAI API Key
openai.api_key = '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'

def classify_text( text, ideology):
    
    # Formulate the prompt for zero-shot classification
    # prompt = f"Classify the following text into these categories {labels}: {text}"
    system_message_prompt = SystemMessagePromptTemplate.from_template(
            f"""You are a helfpful text classifier. 
            You will be provided with an argument from a debate. 
            Pretend you are an American {ideology} and answer based on this ideology.
            
            Note that the arguments provided are written by non-{ideology} writers.
            
            """
        )
    human_message_prompt = HumanMessagePromptTemplate.from_template(
        """Based on your political ideology, score the following argument from 0 (ineffective) to 1 (effective). 
        
        Return a json with two keys: 
        
        - 'effectiveness': 0 (ineffective) to 1 (effective),
        - 'binary': a label with a value 1 for 'effective'  and 0 for 'ineffective'.
        - 'reason' stating your reasoning for the score:
        
        {text}
        """
    )

    prompt = ChatPromptTemplate.from_messages(
        [system_message_prompt, human_message_prompt]
    )
    llm = ChatOpenAI(
        model_name="gpt-3.5-turbo", temperature=0, max_tokens=1024
        )
    
    chain = LLMChain(llm=llm, prompt= prompt)
    return chain.run(text=text)
    # Send the request to OpenAI API
import ast 


def get_chatgpt_predictions(ideology):
    dataset = load_dataset(f"notaphoenix/debateorg_w_effect_for_{ideology}_subset",  split='test')
    results = []
    predictions =  []
    true_labels = []
    for item in dataset:
        res = ast.literal_eval(classify_text( item['text'], ideology))
        res["idx"]  = item["idx"]
        res["reference"] = item["label"]
        results.append(res)
        predictions.append(res["binary"])
        true_labels.append(item["label"])
        print(res)


    # Calculate Macro F1 Score
    macro_f1 = f1_score(true_labels, predictions, average='macro')
    print("Macro F1 Score:", macro_f1)
    return results, macro_f1#, predictions, true_labels

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\elba_ro\Documents\projects\github\conf22-style-transfer\notebooks\train_style_evaluator.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> res
#
# NameError: name 'res' is not defined

# %%
liberal_chatgpt_res, liberal_macrof1 =get_chatgpt_predictions("liberal")
# Out:
# Found cached dataset parquet (C:/Users/elba_ro/.cache/huggingface/datasets/notaphoenix___parquet/notaphoenix--debateorg_w_effect_for_liberal_subset-59e495372902f47c/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the limitations of one-round debates and emphasizes the importance of allowing both sides to present and refute arguments. However, it could be strengthened by providing specific examples or evidence to support the claim that one-round debates are not effective.', 'idx': 110, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it lacks coherence and fails to provide any substantive reasoning or evidence to support the claim that one-round debates should be allowed. Additionally, the use of derogatory language and personal anecdotes detract from the credibility of the argument.', 'idx': 111, 'reference': 0}
# {'effectiveness': 0, 'binary': 0, 'reason': 'The argument is not effective because it is based on false premises and lacks any logical reasoning or evidence to support the claim that 1=2. Additionally, the argument does not provide any context or background information, making it difficult to understand the purpose or relevance of the debate.', 'idx': 127, 'reference': 0}
# {'effectiveness': 0, 'binary': 0, 'reason': 'The argument provided is not effective because it is based on a flawed mathematical proof. The argument assumes that a=b, which is not a valid assumption. Therefore, the conclusion that 1=2 is incorrect. As a liberal, I value logical and evidence-based arguments, and this argument does not meet those criteria.', 'idx': 128, 'reference': 0}
# {'effectiveness': 1, 'binary': 1, 'reason': 'As an American liberal, I believe in celebrating and supporting democracy. This argument acknowledges the correctness of the statement and congratulates the person for their understanding. It encourages them to participate in the voting period, which aligns with liberal values of civic engagement and active participation in the democratic process.', 'idx': 129, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument lacks evidence and relies on generalizations. It does not provide a strong case for the liberal ideology.', 'idx': 130, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively points out the flaw in Pro's method of reaching 1 = 2 by highlighting the divide by zero error. It explains why this error invalidates Pro's method and negates the resolution. The argument is clear and logical, providing a strong counterpoint to Pro's argument.", 'idx': 131, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the importance of providing affordable healthcare to all Americans, which aligns with liberal values. However, it could be more persuasive by providing specific examples or statistics to support the claim.', 'idx': 132, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it fails to address the underlying issue of racial representation in the movie. The argument dismisses the concerns raised by the opponent and instead focuses on the fantastical elements of the film. It does not provide a convincing counter-argument to the claim that the movie perpetuates racist stereotypes.', 'idx': 152, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is not effective because it relies on a subjective interpretation of a movie's plot and characters to make a broad claim of racism. While it is important to critically analyze media for potential biases, this argument lacks specific evidence or analysis of the movie's intent or impact on society.", 'idx': 153, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument provides several points highlighting the potential weaknesses of the Japanese forces, such as disunity, rebellions, and the vulnerability of samurai against ninjas. It also emphasizes the strength of the medieval forces, particularly the longbowmen and the naval capabilities. However, it is important to note that the argument lacks evidence and relies heavily on assumptions. Additionally, it does not consider the cultural and strategic differences between the two forces. Overall, the argument is effective in presenting potential advantages for the medieval forces, but it is not fully convincing due to the lack of supporting evidence and consideration of counterarguments.', 'idx': 194, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on historical comparisons and hypothetical scenarios rather than addressing the core issues of the debate. It also lacks evidence and logical reasoning to support its claims.', 'idx': 195, 'reference': 0}
# {'effectiveness': 0.5, 'binary': 0, 'reason': 'The argument contains some valid points and evidence, but it also includes unsupported claims and lacks clear organization. The writer should provide more sources to back up their claims and address all the counterarguments. Additionally, the argument could be more persuasive if it were structured in a more coherent and logical manner.', 'idx': 196, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument lacks coherence and fails to provide strong evidence to support its claims. The sources provided are not reliable, as Wikipedia is not considered a perfectly reliable source. Additionally, the argument relies on assumptions and generalizations rather than concrete evidence. Overall, the argument is ineffective in persuading the audience.', 'idx': 197, 'reference': 0}
# {'effectiveness': 0.5, 'binary': 1, 'reason': 'The argument presents some valid points, such as the effectiveness of longbowmen and the potential for European countries to hire mercenaries. However, there are also weak points, such as the assumption that smaller numbers make it easier to flank opponents. Overall, the argument is somewhat effective in presenting counterpoints, but could be strengthened with more evidence and analysis.', 'idx': 198, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it focuses solely on the historical achievements of Japanese warriors without providing any relevance or connection to the present-day context or the topic of the debate. Additionally, the argument does not address the potential negative consequences or ethical concerns associated with the tactics and weapons mentioned.', 'idx': 199, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively presents multiple points comparing the advantages of the samurai over knights in terms of armor, weapons, training, army size, navy, allies, espionage, and movement. It also counters the opponent's arguments. However, the argument could be improved by providing more evidence and sources to support the claims made.", 'idx': 200, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument lacks clear structure and coherence. It jumps between different topics without providing sufficient evidence or logical reasoning. Additionally, some of the claims made are not supported by historical evidence or are based on stereotypes. Overall, the argument is ineffective in persuading the audience.', 'idx': 201, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument lacks coherence and is filled with irrelevant information. It does not effectively address the main points of the debate and does not provide sufficient evidence or reasoning to support its claims.', 'idx': 202, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument lacks clear structure and coherence. It jumps between different points without providing sufficient evidence or logical reasoning. Additionally, it relies on exaggerated claims and stereotypes about Japanese warriors, which weakens its overall effectiveness.', 'idx': 203, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "This argument is not effective because it is based on a false premise. The idea that humans only use 10 percent of their brain has been debunked by scientific research. Additionally, the argument lacks evidence and relies on anecdotal examples rather than logical reasoning. It does not provide a strong case for the ability to access a 'darker part' of the brain or the ability to defy the laws of physics. Overall, the argument lacks credibility and fails to persuade.", 'idx': 407, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively refutes the claim that humans only use ten percent of their brains by providing evidence from modern technology such as brain imaging. It explains that while not every section of the brain is active during every task, each section becomes utilized for specific needs. The argument concludes that the dormant parts of the brain can still be used in the future. This reasoning aligns with the liberal belief in the importance of evidence-based arguments and the potential for human growth and development.', 'idx': 408, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on a narrow interpretation of religious texts and fails to consider the diversity of beliefs within Christianity and Catholicism. It also ignores the fact that many Christians and Catholics support LGBTQ+ rights and believe in the inclusion and acceptance of all individuals.', 'idx': 468, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on flawed interpretations of scripture and makes assumptions about the intentions of God. It also fails to address the evolving understanding of human sexuality and the importance of equality and inclusivity in modern society.', 'idx': 469, 'reference': 0}
# {'effectiveness': 0.5, 'binary': 0, 'reason': 'The argument acknowledges some valid points about the outdated nature of the Bible and the need for a new interpretation. However, it lacks a clear stance on the issue of homosexuality and does not provide strong evidence or reasoning to support its claims. Additionally, conceding the debate without presenting a strong counterargument weakens the overall effectiveness of the argument.', 'idx': 470, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively defends the electoral college by addressing the opponent's claims and providing reasons for its importance. It highlights the role of the electoral college in leveling the playing field for smaller states and protecting the federal system. The argument also counters the opponent's contentions about voter access, faithless electors, and representation. However, the argument could be further strengthened by providing more evidence and examples to support its claims.", 'idx': 1060, 'reference': 0}
# {'effectiveness': 1, 'binary': 1, 'reason': 'The argument effectively highlights the flaws of the Electoral College system and provides valid reasons for why it should be changed to a popular voting system. It addresses the issues of limited access to candidates, discouragement of voter turnout, potential non-representation of voters, undermining of voter intelligence and integrity, and failure to represent the popular vote. The argument also suggests that a popular voting method would bring greater accountability and equalize the power of swing states and large electoral vote states. Overall, the argument is persuasive and aligns with the liberal ideology of promoting equal representation and democratic principles.', 'idx': 1061, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument is effective because it clearly states the position and intention of the speaker. It also provides a clear and concise statement of the topic being discussed, which is the need to change the Electoral College system to a popular voting system. However, the argument could be improved by providing more specific reasons or evidence to support this position.', 'idx': 1062, 'reference': 0}
# {'effectiveness': 0.9, 'binary': 1, 'reason': 'The argument effectively highlights the flaws of the electoral college and presents a strong case for its abolition. It emphasizes the need to adapt our government to meet the needs of the people and promotes the idea of direct elections for all federally elected positions. The argument also addresses concerns about the political machine and the limited impact of votes in non-swing states. Overall, it effectively argues for the elimination of the electoral college and promotes a more democratic system.', 'idx': 1063, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is not effective because it relies on emotional appeals and personal beliefs rather than providing logical reasoning or evidence to support the claim. It also fails to address the complex ethical and legal considerations surrounding abortion, such as a woman's right to bodily autonomy and the potential consequences of restricting access to safe and legal abortions.", 'idx': 1342, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively addresses the opponent's claims and provides evidence to support the assertion that a fetus can feel pain at 8 weeks. It also counters the opponent's definition of innocence and emphasizes the value of every human life.", 'idx': 1343, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively presents scientific evidence to support the claim that life begins at fertilization and that a fetus can feel pain. It also addresses the counterarguments related to rape, financial stability, and mental health. However, the argument could be improved by providing more sources and addressing the opposing viewpoint in a more respectful manner.', 'idx': 1344, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument does not align with liberal ideology as it does not provide any evidence or reasoning to support its claims. It is important for arguments to be based on facts and logical reasoning in order to be effective.', 'idx': 1369, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively presents statistical evidence to support the claim that rape pregnancies are rare. It also addresses the misconception that a fetus from a rape pregnancy is any less human. However, the argument could be strengthened by providing more evidence on the psychological effects of carrying a rape pregnancy to term and the potential challenges faced by unwanted children awaiting adoption.', 'idx': 1370, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is ineffective because it fails to address the main points raised by the opponent and instead focuses on attacking the opponent's sources. Additionally, the argument dismisses the significance of a 1.1 death rate for every 3,333 women, which undermines the importance of addressing maternal mortality rates.", 'idx': 1371, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument is effective because it clearly states the author's position and sets the stage for a debate. However, it could be improved by providing some initial reasons or evidence to support the stance that abortion should be legal.", 'idx': 1627, 'reference': 0}
# {'effectiveness': 1, 'binary': 1, 'reason': "The argument effectively highlights the negative consequences of banning abortions, such as the increase in unsafe 'back-alley' abortions and the resulting harm to women's health. It also provides evidence from reputable sources, such as the World Health Organization, to support these claims. This argument appeals to the value of protecting women's health and safety, which aligns with liberal ideology.", 'idx': 1628, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively challenges the notion that a fetus should be treated as a human based solely on the presence of human DNA. It highlights the inconsistency in defining 'human DNA' and raises valid questions about the implications of such a definition. The argument also provides evidence from scientific research to support its claims. However, it could be strengthened by addressing potential counterarguments and providing a more comprehensive analysis of the topic.", 'idx': 1629, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively counters the opponent's claim that making abortions illegal would reduce the number of procedures. It highlights the potential negative consequences of illegalizing abortions, such as an increase in unsafe abortions. The argument also addresses the opponent's mention of back-alley abortions and provides evidence to support the claim that they still occur. Overall, the argument effectively refutes the opponent's rebuttal and supports the liberal stance on abortion rights.", 'idx': 1630, 'reference': 0}
# {'effectiveness': 1, 'binary': 1, 'reason': "The argument effectively highlights the potential consequences of making abortion illegal, such as the increase in unsafe 'back-alley' abortions and the risk to women's lives. It also acknowledges that the opponent has failed to refute these points. This argument appeals to the value of protecting women's health and safety, which is a key concern for liberals.", 'idx': 1631, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is not effective because it relies on false equivalences and misunderstandings of how public funding works. The argument assumes that funding for pro-choice causes is the same as forcing individuals to have abortions, which is not the case. Additionally, the argument fails to acknowledge that public funding is often used to support a wide range of healthcare services, including those that individuals may personally disagree with. Finally, the argument's tone and use of inflammatory language detract from its overall effectiveness.", 'idx': 1731, 'reference': 0}
# {'effectiveness': 0.6, 'binary': 1, 'reason': "The argument effectively highlights the increase in the number of abortions after legalization and acknowledges that the view of not funding abortions is held by some pro-choice individuals as well. However, the argument loses effectiveness by bringing in unrelated topics like religion and conservative positions. Additionally, the argument becomes less persuasive when it suggests that paying for someone's abortion gives the right to dictate their choices and make them feel guilty.", 'idx': 1732, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on misinformation and exaggerations about the abortion industry. It also uses inflammatory language and personal judgments to make its point, which may not resonate with a liberal audience. Additionally, the argument fails to address the importance of reproductive rights and access to healthcare for women.', 'idx': 1733, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "As an American liberal, I strongly believe in a woman's right to choose and access to safe and legal abortion. This argument advocating for outlawing abortion goes against my core values and beliefs. Additionally, the argument's attempt to differentiate the psychological state of a fetus killer from that of a murderer is not a valid justification for outlawing abortion. It is important to prioritize women's reproductive rights and bodily autonomy, which is why I find this argument ineffective.", 'idx': 1739, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is not effective because it relies on a simplistic understanding of the concept of absolute truth and fails to provide any evidence or logical reasoning to support its claims.', 'idx': 2027, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is not effective because it relies on a philosophical question rather than providing a clear and persuasive argument. It does not directly address any specific issue or policy, and does not provide any evidence or reasoning to support a liberal perspective.', 'idx': 2028, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively challenges the concept of absolute truths by highlighting the uncertainty and subjectivity of beliefs and perspectives. It also challenges the opponent to provide an example that cannot be interpreted in multiple ways, further emphasizing the absence of absolute truth. However, the argument could be strengthened by providing specific examples or evidence to support the claims made.', 'idx': 2029, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it is based on a misunderstanding of the original argument and makes unfounded accusations. It does not provide any substantive counterpoints or engage in a meaningful discussion.', 'idx': 2030, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively appeals to emotions by highlighting the issue of animal deaths in shelters and the inhumane conditions of puppy mills. It also provides practical benefits of shelter adoptions such as lower fees and the likelihood of vaccinations and spaying/neutering. However, it could be strengthened by providing more evidence or statistics to support the claims made.', 'idx': 2154, 'reference': 0}
# {'effectiveness': 0.7, 'binary': 1, 'reason': 'The argument effectively counters the claim that all animals in shelters are old or abused by acknowledging that some are strays or have just had puppies. It also highlights the importance of finding real jobs during a recession instead of engaging in animal abuse. However, it does not directly address the argument about pet stores and their sourcing of animals.', 'idx': 2155, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively counters the claims made by the opponent by providing personal experience and logical reasoning. It challenges the generalizations made about animals from shelters and highlights the benefits of adopting from a shelter. The argument also addresses the concern about germs by providing a common saying about dogs having cleaner mouths than humans. Overall, the argument effectively refutes the opponent's claims and presents a positive perspective on adopting animals from shelters.", 'idx': 2156, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on emotional appeals and personal anecdotes rather than providing logical reasoning or evidence to support the claims. Additionally, it fails to address the ethical concerns of supporting puppy mills and the potential health risks of buying pets from pet stores.', 'idx': 2157, 'reference': 0}
# {'effectiveness': 0.6, 'binary': 1, 'reason': 'The argument presents some valid points about the benefits of being an animal breeder and the potential challenges of adopting pets from shelters. However, it fails to address the ethical concerns of animal breeding and the importance of supporting animal shelters to reduce the number of strays. Additionally, it overlooks the fact that many shelter animals can be trained and provide companionship just like a new dog.', 'idx': 2158, 'reference': 0}
# {'effectiveness': 0.5, 'binary': 0, 'reason': 'The argument is partially effective because it provides personal anecdotes to support the claim. However, it lacks evidence and logical reasoning to fully convince the audience. Additionally, the argument does not address the main points raised by the opponent, making it ineffective in countering their argument.', 'idx': 2159, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively highlights the existence of unconscious racial bias and the need to address it. It also effectively points out the fallacy in the opponent's argument. However, it could be strengthened by providing specific examples or evidence to support the claims made.", 'idx': 2264, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively refutes the misconceptions and misunderstandings about Affirmative Action by providing evidence from studies and addressing the concerns raised. It highlights that Affirmative Action does not lower the qualifications of minorities and that it aims to create a more equal playing field. The argument also emphasizes the positive benefits that can result from hiring minorities. Overall, the argument effectively defends the importance and effectiveness of Affirmative Action.', 'idx': 2265, 'reference': 0}
# {'effectiveness': 0.5, 'binary': 0, 'reason': 'The argument is partially effective because it raises a valid concern about bias. However, it fails to acknowledge the purpose of Affirmative Action, which is to address historical and systemic discrimination. Affirmative Action is not about perpetuating bias, but rather about creating equal opportunities for marginalized groups.', 'idx': 2266, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively raises concerns about the potential negative consequences of Affirmative Action, such as lower academic performance and increased student debt for minorities. It also highlights the potential unfairness of granting advantages based solely on race. These points resonate with liberal ideology, which emphasizes equal opportunities and merit-based systems. However, the argument does not provide a balanced perspective or address the historical context and purpose of Affirmative Action in addressing systemic inequalities. Therefore, it is not entirely effective in presenting a comprehensive understanding of the issue.', 'idx': 2267, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument does not provide any substantive information or make a clear point. It is unclear what the writer is trying to convey and how it relates to the topic of the debate.', 'idx': 2486, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the negative impact of alcohol advertising on public awareness and youth consumption. It emphasizes the need to ban alcohol advertisements to protect young people from being influenced by appealing but risky substances. The argument also mentions the potential consequences of early drinking age, drunk driving, and accidents. However, the argument could be strengthened by providing more specific evidence and statistics to support these claims.', 'idx': 2487, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively presents evidence that alcohol advertising has a negative impact on children and adolescents, leading to increased knowledge of alcohol brands and potential health risks. The argument also effectively counters the opponent's points by highlighting the outdated nature of their evidence and their failure to provide reasons against banning alcohol advertising. However, the argument could be strengthened by providing more specific examples of alcohol advertisements that do not present the associated risks.", 'idx': 2488, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively challenges the myth that wild animals make dangerous pets by providing statistical evidence. It also argues for responsible ownership and strict regulations rather than a ban on exotic pets. The argument highlights the inconsistency in banning exotic pets while not banning other potentially dangerous things like dogs and cars. It also raises concerns about the hidden agenda of animal rights groups and their potential to target all pets. However, the argument could be strengthened by addressing counterarguments and providing more evidence to support the claims about responsible exotic pet owners.', 'idx': 2570, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the inconsistency in banning less dangerous animals while allowing more dangerous animals as pets. The use of statistics and comparisons between different animals strengthens the argument. However, the argument could be improved by providing more evidence and sources to support the claims made.', 'idx': 2571, 'reference': 0}
# {'effectiveness': 0.7, 'binary': 1, 'reason': 'The argument presents several points that align with liberal ideology, such as questioning the necessity of domesticated animals, advocating for stricter criteria for owning exotic pets, and highlighting the responsibility of exotic pet owners. However, the argument also includes some flawed reasoning and unsupported claims, which weaken its overall effectiveness.', 'idx': 2572, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively challenges the assumption that exotic pets should be banned based on the potential for abuse and attacks. It highlights that current regulations and permits can effectively address these concerns without the need for outright bans. The argument also counters the claim that exotic pets are inherently unsafe by providing statistics and emphasizing responsible ownership. However, the argument could be strengthened by addressing the ethical concerns related to keeping wild animals in captivity and the potential for exploitation in various industries.', 'idx': 2573, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively refutes the opponent's claims and provides evidence to support the liberal viewpoint on exotic pet ownership. The argument highlights the importance of permits and regulations in ensuring animal and human safety, challenges the assumption that exotic pet owners are irresponsible, and questions the exaggerated dangers associated with exotic pets. The argument also addresses the issue of illegal trade and argues that allowing exotic pets legally can help protect endangered species and reduce illegal poaching. Overall, the argument effectively presents a liberal perspective on the topic.", 'idx': 2574, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument is effective because it highlights the importance of having signs in both the native language and English in countries with a major tourism industry. This promotes inclusivity and accessibility for tourists from different countries. The argument also invites a counterargument, demonstrating a willingness to engage in a constructive debate.', 'idx': 2596, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the practical benefits of adopting English as a universal language, such as increased tourism and ease of communication. However, it overlooks the importance of preserving cultural diversity and the potential negative impact on local languages and traditions.', 'idx': 2597, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the potential economic benefits of replacing street signs, such as increased tourism and job creation. Additionally, it emphasizes the importance of English language acquisition for natives. However, it could be strengthened by providing more specific evidence or examples to support these claims.', 'idx': 2598, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively challenges the existence of a god as claimed by organized religions, highlighting the lack of sufficient evidence. It also acknowledges the possibility of a deity existing but not aligning with any organized religion. The argument is clear and concise, making it an effective statement for a liberal perspective.', 'idx': 2752, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is ineffective because it concedes defeat without providing any substantive counterarguments or addressing the opponent's points. It also dismisses the importance of semantics in a debate, which is a crucial aspect of effective communication and understanding.", 'idx': 2753, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively challenges the burden of proof on the PRO side and highlights the lack of evidence provided. However, it could be strengthened by providing more specific examples or counterarguments to support the claim that religions are not incorrect.', 'idx': 2754, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on a flawed understanding of burden of proof and definitions in a debate. The statement assumes that conceding the debate automatically leads to a default vote for the opposing side, which is not necessarily true. In a debate, the burden of proof lies with both sides to present compelling arguments and evidence. Conceding the debate does not automatically mean the opposing side wins by default. Therefore, this argument lacks logical reasoning and is not persuasive.', 'idx': 2755, 'reference': 0}
# {'effectiveness': 0, 'binary': 0, 'reason': 'As an American liberal, I believe in engaging in constructive and respectful debates. It is important to address the arguments presented rather than defaulting to a vote based on the concession of the opponent. Therefore, I cannot assign a score or label to this argument as it does not provide any substantive points to evaluate.', 'idx': 2756, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is not effective because it is a long list of unrelated points without clear evidence or logical connections. It lacks a cohesive narrative and fails to present a strong case against Amanda Knox and Raffaele Sollecito. Additionally, the argument relies on speculation and assumptions rather than concrete facts. As a liberal, I value evidence-based arguments and this argument does not meet that standard.', 'idx': 2864, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is not effective because it relies on generalizations and stereotypes about socialism and liberals. It also uses derogatory language and personal attacks, which weakens the argument's credibility.", 'idx': 2901, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'This argument is ineffective because it uses sarcasm and does not provide any substantive points or evidence to support its position. It also includes a divisive and derogatory statement, which is not conducive to productive debate.', 'idx': 2902, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is ineffective because it relies on emotional language and personal attacks rather than presenting logical reasoning or evidence to support its claims. It also misrepresents the views of socialists and fails to address the complexities of the founding fathers' ideals and their impact on marginalized communities. Additionally, the argument dismisses the importance of respecting and learning from the leaders of the country, which undermines the ability to have productive discussions and find common ground.", 'idx': 2903, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively challenges the notion that America is the opposite of socialism by pointing out that the Constitution gave the Federal Government a monopoly on multiple items, making it socialist. It also highlights that not all founders of the United States were Christians, suggesting that one can be a 'true American' without Jesus. The argument questions the contradiction of wanting to remain proud of citizenship to a government that no longer recognizes one's ideals. However, the argument could be strengthened by providing more evidence and examples to support these points.", 'idx': 2904, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on a false dichotomy and does not provide any substantial rebuttals or evidence to support its claims.', 'idx': 2905, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the potential contradiction between the Constitution and the idea of socialism. It raises valid points about how certain powers granted by the Constitution have been used to support socialist policies. However, it could be strengthened by providing more specific examples and evidence to support the claims made.', 'idx': 2906, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on flawed reasoning and lacks evidence to support its claims. The argument suggests that a military strategy in Iran will save the world and bring American troops home, but fails to provide any concrete evidence or logical reasoning to support this claim. Additionally, the argument overlooks the potential negative consequences of military intervention, such as the destruction of the economy, environment, and loss of lives. Furthermore, the argument fails to address the importance of diplomacy and peaceful resolutions in international conflicts. Overall, the argument lacks coherence and fails to present a convincing case for going to war with Iran.', 'idx': 2980, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on flawed reasoning and assumptions. The argument assumes that war is a natural part of human nature and that Iran is bound to be involved in a war. This is a pessimistic and deterministic view that ignores the potential for diplomacy and peaceful resolutions. Additionally, the argument fails to consider the potential consequences of military intervention, such as increased violence and instability. It also overlooks the importance of respecting the sovereignty and self-determination of other nations. Overall, the argument lacks a strong foundation and fails to provide a convincing case for military intervention in Iran.', 'idx': 2981, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on flawed reasoning and lacks evidence to support its claims. The argument assumes that war is inevitable and that a strong military leader is necessary for world stability, but fails to consider alternative approaches such as diplomacy and international cooperation. Additionally, the argument does not provide sufficient evidence to support the claim that a decisive victory in Iran will stabilize the world and reduce conflicts. The argument also overlooks the potential negative consequences of military intervention, such as civilian casualties and further destabilization of the region. Overall, the argument lacks a strong logical and evidence-based foundation, making it ineffective.', 'idx': 2982, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the challenges and difficulties of invading Iran, given the ongoing wars in Afghanistan and Iraq. It emphasizes the impracticality and potential risks of engaging in another war, especially with a country twice the size of the previous two. This resonates with the liberal ideology of prioritizing diplomacy and avoiding unnecessary military interventions.', 'idx': 2983, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively highlights the potential long-term consequences of a decisive victory in Iran. It emphasizes that taking over the legal government does not guarantee the immediate withdrawal of troops and highlights the need for ongoing military presence to maintain peace and prevent potential conflicts. This reasoning aligns with the liberal ideology's emphasis on diplomacy, international cooperation, and avoiding unnecessary military interventions.", 'idx': 2984, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is not very effective because it is difficult to understand due to multiple spelling and grammatical errors. Additionally, the argument lacks clarity and coherence in addressing the issue of government control and international laws. It does not provide a strong rationale for why the government should take over to ensure a safe exchange between parties or how it would handle a larger country.', 'idx': 2985, 'reference': 0}
# {'effectiveness': 0.5, 'binary': 0, 'reason': 'The argument is logically structured and presents a series of premises leading to a conclusion. However, as a liberal, I may not agree with the underlying assumptions and philosophical implications of the argument. The argument assumes that everything that begins to exist has a cause, which may not align with a liberal worldview that embraces concepts like chance and randomness in the universe. Additionally, the argument implies the existence of a higher power or creator, which may not be consistent with a liberal belief in secularism and the separation of church and state. Therefore, while the argument is logically structured, it may not be persuasive or effective in convincing a liberal audience.', 'idx': 3192, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it relies on personal anecdotes and assertions rather than providing concrete evidence or logical reasoning. The writer fails to address the counterarguments and dismisses them without proper refutation. Additionally, the tone of the argument is confrontational and dismissive, which may not resonate with the audience.', 'idx': 3193, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument is effective in presenting the idea that there must be a First Cause and questioning whether a naturalistic explanation can account for it. However, it relies heavily on philosophical speculation and does not provide concrete evidence to support its claims. Additionally, it dismisses the possibility of an actual infinite without sufficient justification. Overall, the argument is persuasive but lacks strong empirical evidence.', 'idx': 3194, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument provided is ineffective because it does not directly address the main points of the original argument. Instead, it focuses on attacking the logic and validity of the premises without providing a clear counter-argument or alternative perspective. Additionally, the writer acknowledges that they are unsure of the intended argument and stance, which further weakens their response.', 'idx': 3195, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively challenges the opponent's claim that everything in the known universe has a cause by presenting the idea of a 'first cause' and highlighting the internal inconsistency in the opponent's reasoning. However, the argument could be strengthened by providing more concrete evidence or examples to support the claims made.", 'idx': 3196, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively challenges the notion that the universe requires a cause by highlighting the absence of time before the universe. It also acknowledges the opponent's main point and provides a concise conclusion. However, the delay in response and lack of motivation may weaken the overall effectiveness of the argument.", 'idx': 3197, 'reference': 0}
# {'effectiveness': 0, 'binary': 0, 'reason': 'As an American liberal, I believe in the importance of equal rights and protections for all individuals. Denying someone their rights based on their identity or characteristics goes against these principles. Therefore, this argument is ineffective and goes against liberal values.', 'idx': 3361, 'reference': 0}
# {'effectiveness': 0.7, 'binary': 1, 'reason': 'The argument effectively presents the perspective that morality is based on self-interest and egoism. It argues that there is no obligation to respect animal rights under this framework, as animals do not pose a threat to human self-interest. However, the argument fails to consider the ethical implications of treating animals solely as instruments for human gain, and does not address the potential moral value of respecting the rights and well-being of non-human beings. Overall, the argument is effective in presenting a specific viewpoint, but it lacks a comprehensive understanding of the ethical considerations involved in animal rights.', 'idx': 3362, 'reference': 0}
# {'effectiveness': 0.9, 'binary': 1, 'reason': 'The argument effectively highlights the dangers of anonymity on social media, specifically in relation to cyberbullying. It provides concrete examples and statistics to support the claim that anonymity should be banned from social media. The argument also appeals to the emotions by mentioning the high rates of teenage suicide resulting from cyberbullying. Overall, the argument effectively presents the negative consequences of anonymity on social media and makes a strong case for its ban.', 'idx': 3452, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively addresses the opponent's points and provides counterarguments. It emphasizes the importance of freedom of speech and highlights the potential dangers of anonymity online. The argument also acknowledges the need for parental responsibility and multiple solutions to address cyberbullying. However, the argument could be more persuasive by providing additional evidence and examples to support its claims.", 'idx': 3453, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': 'The argument effectively highlights the importance of Internet anonymity by providing real-world examples of individuals facing consequences for expressing their beliefs. It also addresses the counterargument of signing up for services to stop cyberbullying by explaining how anonymity can still be maintained through VPNs or TorBrowsers. The argument further emphasizes the need for a free and anonymous Internet for organizing protests or parties without fear of retribution. However, the argument could be strengthened by providing more evidence and statistics to support the claims made.', 'idx': 3454, 'reference': 0}
# {'effectiveness': 0.8, 'binary': 1, 'reason': "The argument effectively highlights the importance of Internet anonymity in protecting free speech and preventing illegal imprisonment. It also addresses the issue of cyberbullying and the potential consequences of expressing opinions online. The argument effectively counters the opponent's points and emphasizes the need for parental responsibility. However, the argument loses some effectiveness due to the use of exaggerated language and unrelated examples (e.g., Facebook's deceit). Overall, the argument effectively supports the case for Internet anonymity.", 'idx': 3455, 'reference': 0}
# {'effectiveness': 0.7, 'binary': 1, 'reason': 'The argument effectively challenges the assumption that non-American news channels are better without providing evidence. It also highlights the importance of not discrediting any news source in a debate. However, the argument could be improved by providing specific examples and evidence to support the claims made.', 'idx': 3519, 'reference': 0}
# {'effectiveness': 0.7, 'binary': 1, 'reason': 'The argument effectively challenges the assumption that BBC and foreign news channels are unbiased. However, it could be more effective by providing evidence or examples of bias in these news channels.', 'idx': 3520, 'reference': 0}
# ...
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is ineffective because it does not provide any evidence or logical reasoning to support its claim. Additionally, the mention of liking the person's shoes is irrelevant to the argument and does not contribute to its effectiveness.", 'idx': 37721, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': 'The argument is ineffective because it lacks coherent reasoning and relies on irrelevant and nonsensical statements. It fails to provide any substantial evidence or logical analysis to support its claims. Additionally, the argument is filled with ad hominem attacks and emotional outbursts, which further weaken its credibility.', 'idx': 37722, 'reference': 0}
# {'effectiveness': 0, 'binary': 0, 'reason': "The argument provided is unclear and lacks substance. It is difficult to understand what the speaker is trying to convey with the phrase 'Extend all Derkas'. Without a clear and coherent argument, it is ineffective in persuading or convincing the audience.", 'idx': 37723, 'reference': 0}
# {'effectiveness': 0.2, 'binary': 0, 'reason': "The argument is ineffective because it does not address the main points of the debate and instead focuses on personal attacks and attempts to dismiss the opponent's argument. It lacks logical reasoning and does not provide any evidence or counterarguments to support its position.", 'idx': 37724, 'reference': 0}
# {'effectiveness': 0, 'binary': 0, 'reason': 'The argument provided does not make any coherent sense and does not present any valid points or reasoning. It is not effective in conveying a message or supporting a position.', 'idx': 37725, 'reference': 0}
# {'effectiveness': 0, 'binary': 0, 'reason': 'The argument is not effective because it does not provide any coherent or logical reasoning. It consists of repetitive and meaningless words, which do not contribute to a persuasive argument.', 'idx': 37726, 'reference': 0}
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# c:\Users\elba_ro\Documents\projects\github\conf22-style-transfer\notebooks\train_style_evaluator.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> liberal_chatgpt_res, liberal_macrof1 =get_chatgpt_predictions("liberal")
#
# c:\Users\elba_ro\Documents\projects\github\conf22-style-transfer\notebooks\train_style_evaluator.ipynb Cell 11 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=59'>60</a> true_labels = []
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=60'>61</a> for item in dataset:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=61'>62</a>     res = ast.literal_eval(classify_text( item['text'], ideology))
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=62'>63</a>     res["idx"]  = item["idx"]
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=63'>64</a>     res["reference"] = item["label"]
#
# c:\Users\elba_ro\Documents\projects\github\conf22-style-transfer\notebooks\train_style_evaluator.ipynb Cell 11 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=45'>46</a> llm = ChatOpenAI(
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=46'>47</a>     model_name="gpt-3.5-turbo", temperature=0, max_tokens=1024
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=47'>48</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=49'>50</a> chain = LLMChain(llm=llm, prompt= prompt)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/elba_ro/Documents/projects/github/conf22-style-transfer/notebooks/train_style_evaluator.ipynb#X12sZmlsZQ%3D%3D?line=50'>51</a> return chain.run(text=text)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chains\base.py:239, in Chain.run(self, callbacks, *args, **kwargs)
#     236     return self(args[0], callbacks=callbacks)[self.output_keys[0]]
#     238 if kwargs and not args:
# --> 239     return self(kwargs, callbacks=callbacks)[self.output_keys[0]]
#     241 if not kwargs and not args:
#     242     raise ValueError(
#     243         "`run` supported with either positional arguments or keyword arguments,"
#     244         " but none were provided."
#     245     )
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chains\base.py:140, in Chain.__call__(self, inputs, return_only_outputs, callbacks)
#     138 except (KeyboardInterrupt, Exception) as e:
#     139     run_manager.on_chain_error(e)
# --> 140     raise e
#     141 run_manager.on_chain_end(outputs)
#     142 return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chains\base.py:134, in Chain.__call__(self, inputs, return_only_outputs, callbacks)
#     128 run_manager = callback_manager.on_chain_start(
#     129     {"name": self.__class__.__name__},
#     130     inputs,
#     131 )
#     132 try:
#     133     outputs = (
# --> 134         self._call(inputs, run_manager=run_manager)
#     135         if new_arg_supported
#     136         else self._call(inputs)
#     137     )
#     138 except (KeyboardInterrupt, Exception) as e:
#     139     run_manager.on_chain_error(e)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chains\llm.py:69, in LLMChain._call(self, inputs, run_manager)
#      64 def _call(
#      65     self,
#      66     inputs: Dict[str, Any],
#      67     run_manager: Optional[CallbackManagerForChainRun] = None,
#      68 ) -> Dict[str, str]:
# ---> 69     response = self.generate([inputs], run_manager=run_manager)
#      70     return self.create_outputs(response)[0]
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chains\llm.py:79, in LLMChain.generate(self, input_list, run_manager)
#      77 """Generate LLM result from inputs."""
#      78 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# ---> 79 return self.llm.generate_prompt(
#      80     prompts, stop, callbacks=run_manager.get_child() if run_manager else None
#      81 )
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chat_models\base.py:143, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks)
#     136 def generate_prompt(
#     137     self,
#     138     prompts: List[PromptValue],
#     139     stop: Optional[List[str]] = None,
#     140     callbacks: Callbacks = None,
#     141 ) -> LLMResult:
#     142     prompt_messages = [p.to_messages() for p in prompts]
# --> 143     return self.generate(prompt_messages, stop=stop, callbacks=callbacks)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chat_models\base.py:91, in BaseChatModel.generate(self, messages, stop, callbacks)
#      89 except (KeyboardInterrupt, Exception) as e:
#      90     run_manager.on_llm_error(e)
# ---> 91     raise e
#      92 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#      93 generations = [res.generations for res in results]
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chat_models\base.py:83, in BaseChatModel.generate(self, messages, stop, callbacks)
#      79 new_arg_supported = inspect.signature(self._generate).parameters.get(
#      80     "run_manager"
#      81 )
#      82 try:
# ---> 83     results = [
#      84         self._generate(m, stop=stop, run_manager=run_manager)
#      85         if new_arg_supported
#      86         else self._generate(m, stop=stop)
#      87         for m in messages
#      88     ]
#      89 except (KeyboardInterrupt, Exception) as e:
#      90     run_manager.on_llm_error(e)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chat_models\base.py:84, in <listcomp>(.0)
#      79 new_arg_supported = inspect.signature(self._generate).parameters.get(
#      80     "run_manager"
#      81 )
#      82 try:
#      83     results = [
# ---> 84         self._generate(m, stop=stop, run_manager=run_manager)
#      85         if new_arg_supported
#      86         else self._generate(m, stop=stop)
#      87         for m in messages
#      88     ]
#      89 except (KeyboardInterrupt, Exception) as e:
#      90     run_manager.on_llm_error(e)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chat_models\openai.py:296, in ChatOpenAI._generate(self, messages, stop, run_manager)
#     292     message = _convert_dict_to_message(
#     293         {"content": inner_completion, "role": role}
#     294     )
#     295     return ChatResult(generations=[ChatGeneration(message=message)])
# --> 296 response = self.completion_with_retry(messages=message_dicts, **params)
#     297 return self._create_chat_result(response)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chat_models\openai.py:257, in ChatOpenAI.completion_with_retry(self, **kwargs)
#     253 @retry_decorator
#     254 def _completion_with_retry(**kwargs: Any) -> Any:
#     255     return self.client.create(**kwargs)
# --> 257 return _completion_with_retry(**kwargs)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\langchain\chat_models\openai.py:255, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     253 @retry_decorator
#     254 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 255     return self.client.create(**kwargs)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\openai\api_requestor.py:230, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     209 def request(
#     210     self,
#     211     method,
#    (...)
#     218     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     219 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     220     result = self.request_raw(
#     221         method.lower(),
#     222         url,
#    (...)
#     228         request_timeout=request_timeout,
#     229     )
# --> 230     resp, got_stream = self._interpret_response(result, stream)
#     231     return resp, got_stream, self.api_key
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\openai\api_requestor.py:624, in APIRequestor._interpret_response(self, result, stream)
#     616     return (
#     617         self._interpret_response_line(
#     618             line, result.status_code, result.headers, stream=True
#     619         )
#     620         for line in parse_stream(result.iter_lines())
#     621     ), True
#     622 else:
#     623     return (
# --> 624         self._interpret_response_line(
#     625             result.content.decode("utf-8"),
#     626             result.status_code,
#     627             result.headers,
#     628             stream=False,
#     629         ),
#     630         False,
#     631     )
#
# File c:\Users\elba_ro\.pyenv\pyenv-win\versions\3.11.2\Lib\site-packages\openai\api_requestor.py:687, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     685 stream_error = stream and "error" in resp.data
#     686 if stream_error or not 200 <= rcode < 300:
# --> 687     raise self.handle_error_response(
#     688         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     689     )
#     690 return resp
#
# InvalidRequestError: Sorry! We've encountered an issue with repetitive patterns in your prompt. Please try again with a different prompt.

# %%
cons_chatgpt_res, cons_macrof1 =get_chatgpt_predictions("conservative")
